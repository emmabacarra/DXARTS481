# %% [markdown]
# Songs - The participant's mood/color/emotion perception of songs
#     SongID - ID (also filename) of song in our dataset
#     Perceived - A list of emotions which the song perceived by the participant
#         V, A - The position of the chosen perceived emotion in the valence-arousal space [0,1]
#     SongColor - The participant's choice of best-matching color of a song in the HSV space (H - hue [0-1], S - saturation [0-1], V -value [0-1])
#
#
# convert mp4 audio to delta capstrum feature vector?
#
# input: dcf vector --> array of vectors
#
# test/output: perceivedVA, songcolor --> sort by song_id (rows), columns will be HSV color values

# %%
from bs4 import BeautifulSoup
import os
import librosa
import numpy as np
from collections import defaultdict
import csv
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
def extract_features(file_path, sr=22050, duration=5.0, hop_size=2.5):
    """
    Extracts delta cepstrum features using a sliding window approach.
    :param file_path: Path to the audio file.
    :param sr: Sampling rate.
    :param duration: Fixed length of each segment (seconds).
    :param hop_size: Overlapping step size between segments (seconds).
    :return: A list of feature arrays.
    """
    y, _ = librosa.load(file_path, sr=sr)
    segment_length = int(sr * duration)
    hop_length = int(sr * hop_size)

    features = []
    
    # Iterate over the audio in sliding windows
    for start in range(0, len(y) - segment_length + 1, hop_length):
        y_segment = y[start:start + segment_length]
        
        mfcc = librosa.feature.mfcc(y=y_segment, sr=sr, n_mfcc=13) # mel-frequency cepstrum features
        dcf = librosa.feature.delta(mfcc) # delta cepstrum features

        features.append(dcf)

    return np.array(features)

def average_hsv(hsv_colors):
    h_cos = np.cos(np.radians(hsv_colors[:, 0]))
    h_sin = np.sin(np.radians(hsv_colors[:, 0]))

    avg_h_cos = np.mean(h_cos)
    avg_h_sin = np.mean(h_sin)
    avg_h = np.degrees(np.arctan2(avg_h_sin, avg_h_cos)) % 360
    avg_s = np.mean(hsv_colors[:, 1])
    avg_v = np.mean(hsv_colors[:, 2])
    
    return avg_h, avg_s, avg_v

# %%
n_songs = len(os.listdir('../../../moodo/audio'))
for i, file in enumerate(os.listdir('../../../moodo/audio'), 1):
    
    song_id = file.split('.')[0]
    file_path = os.path.join('../../../moodo/audio', file)
    
    features = extract_features(file_path)
    
    os.makedirs('../../../moodo/audio_features2', exist_ok=True)
    
    np.save(f'../../../moodo/audio_features2/{song_id}.npy', features)
    print(f'Saved {i}/{n_songs} songs           ', end='\r')
# Out:
# Saved 200/200 songs

# %%
with open('../../../moodo/dataset.xml', 'r') as file:
    soup = BeautifulSoup(file, 'xml')
    
hsv_values = defaultdict(list)
perceived_emotions = defaultdict(list)

emotions = []
rows = []

for item in soup.find_all('item'):
    for songs_survey_list in item.find_all('Songs'):
        for song in songs_survey_list.find_all('item'):
            song_id = song.find('SongID').text 
            song_color = song.find('SongColor') # participant's best match to a color in HSV
            
            h = float(song_color.find('H').text)
            s = float(song_color.find('S').text)
            v = float(song_color.find('V').text)
            
            perceived_emotions = song.find('Perceived') # participant's perceived emotions
            for emotion in perceived_emotions.find_all(True): # True: all tags inside 'Perceived' (e.g. 'Happy', 'Sad', 'Angry', etc.)
                emotion_name = emotion.name
                
                valence = emotion.find('V')
                arousal = emotion.find('A')
                
                if emotion_name not in emotions and emotion_name not in ['V', 'A']:
                    emotions.append(emotion_name)
                
                if valence and arousal:  
                    rows.append({
                        'SongID': song_id, 
                        'H': h, 
                        'S': s, 
                        'V': v,
                        'Val': float(valence.text),
                        'Ar': float(arousal.text),
                        'Emotion': emotion_name
                        })

df = pd.DataFrame(rows)

for song_id in df['SongID'].unique():
    song = df[df['SongID'] == song_id]
    
    emotions_listed = song['Emotion'].unique()
    n_participants = len(song)
    
    print(f'\nSongID {song_id} | {n_participants} participants')
    print(f'Emotions: {emotions_listed}')
# Out:
# SongID 101 | 50 participants
# Emotions: ['Liveliness' 'Anger' 'Fear' 'Anticipation' 'Surprise' 'Longing'
#  'Gloominess' 'Inspiring' 'Sadness']
#
# SongID 153 | 83 participants
# Emotions: ['Sadness' 'Relaxed' 'Calmness' 'Liveliness' 'Inspiring' 'Longing'
#  'Dreamy' 'Joy' 'Happiness' 'Anticipation' 'Gloominess' 'Fear' 'Surprise'
#  'Anger']
#
# SongID 209 | 36 participants
# Emotions: ['Dreamy' 'Gloominess' 'Calmness' 'Relaxed' 'Sadness' 'Happiness'
#  'Longing']
#
# SongID 242 | 74 participants
# Emotions: ['Surprise' 'Calmness' 'Anticipation' 'Joy' 'Longing' 'Liveliness' 'Anger'
#  'Fear' 'Dreamy' 'Inspiring' 'Relaxed' 'Gloominess']
#
# SongID 504 | 63 participants
# Emotions: ['Liveliness' 'Fear' 'Inspiring' 'Gloominess' 'Anticipation' 'Sadness'
#  'Longing' 'Anger' 'Dreamy' 'Joy' 'Relaxed' 'Happiness']
#
# SongID 513 | 94 participants
# Emotions: ['Gloominess' 'Happiness' 'Longing' 'Relaxed' 'Dreamy' 'Sadness' 'Joy'
#  'Liveliness' 'Surprise' 'Anticipation' 'Anger' 'Fear' 'Calmness'
#  'Inspiring']
#
# SongID 525 | 95 participants
# Emotions: ['Sadness' 'Anger' 'Liveliness' 'Happiness' 'Inspiring' 'Relaxed'
#  'Calmness' 'Joy' 'Dreamy' 'Anticipation' 'Longing' 'Surprise']
#
# SongID 551 | 90 participants
# Emotions: ['Longing' 'Sadness' 'Gloominess' 'Inspiring' 'Dreamy' 'Calmness' 'Fear'
#  'Anticipation' 'Relaxed']
#
# SongID 607 | 48 participants
# Emotions: ['Surprise' 'Anticipation' 'Anger' 'Fear' 'Dreamy' 'Liveliness' 'Calmness'
#  'Gloominess' 'Inspiring']
#
# SongID 618 | 46 participants
# Emotions: ['Sadness' 'Anger' 'Fear' 'Inspiring' 'Surprise' 'Anticipation'
#  'Liveliness' 'Dreamy' 'Gloominess']
#
# SongID 104 | 88 participants
# Emotions: ['Anticipation' 'Anger' 'Fear' 'Dreamy' 'Surprise' 'Longing' 'Inspiring'
#  'Sadness' 'Gloominess' 'Calmness' 'Relaxed']
#
# SongID 172 | 84 participants
# Emotions: ['Joy' 'Liveliness' 'Happiness' 'Surprise' 'Relaxed' 'Inspiring'
#  'Anticipation' 'Anger' 'Fear' 'Dreamy' 'Longing' 'Calmness']
#
# SongID 204 | 137 participants
# Emotions: ['Relaxed' 'Dreamy' 'Inspiring' 'Calmness' 'Gloominess' 'Anticipation'
#  'Longing' 'Sadness' 'Liveliness' 'Happiness' 'Joy']
#
# SongID 367 | 38 participants
# Emotions: ['Anticipation' 'Longing' 'Happiness' 'Anger' 'Inspiring' 'Fear'
#  'Gloominess' 'Liveliness' 'Surprise']
#
# SongID 503 | 73 participants
# Emotions: ['Inspiring' 'Relaxed' 'Anticipation' 'Fear' 'Dreamy' 'Happiness'
#  'Longing' 'Anger' 'Surprise' 'Liveliness' 'Joy' 'Gloominess']
#
# SongID 555 | 51 participants
# Emotions: ['Dreamy' 'Gloominess' 'Relaxed' 'Inspiring' 'Longing' 'Sadness'
#  'Calmness' 'Joy' 'Anticipation' 'Happiness']
#
# SongID 565 | 78 participants
# Emotions: ['Calmness' 'Joy' 'Dreamy' 'Gloominess' 'Sadness' 'Longing' 'Anger'
#  'Happiness' 'Relaxed' 'Anticipation' 'Liveliness' 'Inspiring' 'Fear'
#  'Surprise']
#
# SongID 109 | 116 participants
# Emotions: ['Anticipation' 'Anger' 'Fear' 'Surprise' 'Liveliness' 'Gloominess'
#  'Longing' 'Joy' 'Sadness' 'Inspiring' 'Happiness' 'Relaxed' 'Dreamy']
#
# SongID 155 | 74 participants
# Emotions: ['Joy' 'Anticipation' 'Inspiring' 'Dreamy' 'Happiness' 'Liveliness'
#  'Relaxed' 'Longing' 'Surprise' 'Calmness']
#
# SongID 156 | 76 participants
# Emotions: ['Gloominess' 'Longing' 'Anticipation' 'Surprise' 'Dreamy' 'Inspiring'
#  'Liveliness' 'Happiness' 'Joy' 'Relaxed' 'Anger' 'Sadness' 'Calmness']
#
# SongID 181 | 48 participants
# Emotions: ['Sadness' 'Anticipation' 'Dreamy' 'Gloominess' 'Longing' 'Relaxed'
#  'Calmness' 'Inspiring' 'Surprise']
#
# SongID 190 | 68 participants
# Emotions: ['Gloominess' 'Longing' 'Anticipation' 'Dreamy' 'Calmness' 'Surprise'
#  'Fear' 'Sadness' 'Liveliness' 'Inspiring' 'Relaxed']
#
# SongID 196 | 70 participants
# Emotions: ['Gloominess' 'Longing' 'Anticipation' 'Fear' 'Anger' 'Liveliness'
#  'Inspiring' 'Happiness' 'Relaxed' 'Surprise' 'Joy' 'Dreamy' 'Calmness']
#
# SongID 404 | 45 participants
# Emotions: ['Sadness' 'Gloominess' 'Dreamy' 'Longing' 'Surprise' 'Calmness' 'Joy'
#  'Relaxed' 'Liveliness' 'Happiness' 'Inspiring']
#
# SongID 539 | 71 participants
# Emotions: ['Longing' 'Fear' 'Dreamy' 'Happiness' 'Liveliness' 'Relaxed' 'Calmness'
#  'Inspiring' 'Sadness' 'Gloominess' 'Joy' 'Anger' 'Anticipation']
#
# SongID 615 | 48 participants
# Emotions: ['Sadness' 'Gloominess' 'Anticipation' 'Fear' 'Anger' 'Surprise'
#  'Inspiring' 'Relaxed' 'Dreamy']
#
# SongID 130 | 91 participants
# Emotions: ['Relaxed' 'Dreamy' 'Calmness' 'Longing' 'Anticipation' 'Inspiring'
#  'Happiness' 'Gloominess' 'Surprise' 'Fear' 'Sadness' 'Joy' 'Liveliness'
#  'Anger']
#
# SongID 161 | 87 participants
# Emotions: ['Relaxed' 'Dreamy' 'Longing' 'Inspiring' 'Gloominess' 'Anticipation'
#  'Liveliness' 'Fear' 'Surprise' 'Calmness' 'Joy' 'Happiness' 'Sadness'
#  'Anger']
#
# SongID 415 | 56 participants
# Emotions: ['Joy' 'Relaxed' 'Calmness' 'Dreamy' 'Happiness' 'Liveliness' 'Sadness'
#  'Gloominess' 'Longing' 'Anticipation' 'Inspiring' 'Anger' 'Fear']
#
# SongID 417 | 79 participants
# Emotions: ['Relaxed' 'Inspiring' 'Dreamy' 'Happiness' 'Joy' 'Anticipation'
#  'Calmness' 'Sadness' 'Liveliness' 'Longing' 'Surprise' 'Fear']
#
# SongID 529 | 106 participants
# Emotions: ['Liveliness' 'Happiness' 'Joy' 'Relaxed' 'Sadness' 'Anger' 'Surprise'
#  'Anticipation' 'Dreamy' 'Inspiring' 'Longing']
#
# SongID 537 | 62 participants
# Emotions: ['Inspiring' 'Happiness' 'Joy' 'Relaxed' 'Calmness' 'Dreamy' 'Liveliness'
#  'Anticipation' 'Longing' 'Sadness' 'Anger' 'Gloominess' 'Surprise']
#
# SongID 572 | 95 participants
# Emotions: ['Anticipation' 'Inspiring' 'Relaxed' 'Longing' 'Happiness' 'Calmness'
#  'Dreamy' 'Joy' 'Liveliness' 'Surprise' 'Sadness' 'Gloominess' 'Fear']
#
# SongID 605 | 76 participants
# Emotions: ['Anticipation' 'Inspiring' 'Relaxed' 'Calmness' 'Gloominess' 'Fear'
#  'Surprise' 'Dreamy' 'Longing' 'Sadness' 'Liveliness' 'Anger' 'Joy'
#  'Happiness']
#
# SongID 616 | 48 participants
# Emotions: ['Fear' 'Anticipation' 'Anger' 'Liveliness' 'Sadness' 'Gloominess'
#  'Calmness' 'Surprise' 'Longing' 'Dreamy']
#
# SongID 164 | 109 participants
# Emotions: ['Surprise' 'Joy' 'Calmness' 'Anticipation' 'Dreamy' 'Inspiring' 'Anger'
#  'Fear' 'Happiness' 'Gloominess' 'Longing' 'Relaxed' 'Sadness'
#  'Liveliness']
#
# SongID 186 | 59 participants
# Emotions: ['Fear' 'Longing' 'Surprise' 'Sadness' 'Anticipation' 'Inspiring'
#  'Gloominess' 'Calmness' 'Relaxed' 'Dreamy' 'Anger' 'Joy']
#
# SongID 420 | 72 participants
# Emotions: ['Calmness' 'Joy' 'Liveliness' 'Happiness' 'Inspiring' 'Longing' 'Dreamy'
#  'Anticipation' 'Sadness' 'Gloominess' 'Relaxed' 'Fear' 'Surprise']
#
# SongID 515 | 119 participants
# Emotions: ['Dreamy' 'Joy' 'Happiness' 'Liveliness' 'Relaxed' 'Calmness' 'Longing'
#  'Inspiring' 'Anticipation' 'Sadness' 'Gloominess' 'Anger' 'Fear']
#
# SongID 520 | 77 participants
# Emotions: ['Calmness' 'Gloominess' 'Anticipation' 'Longing' 'Liveliness' 'Relaxed'
#  'Inspiring' 'Happiness' 'Sadness' 'Anger' 'Dreamy' 'Joy' 'Fear']
#
# SongID 542 | 86 participants
# Emotions: ['Dreamy' 'Relaxed' 'Inspiring' 'Sadness' 'Calmness' 'Joy' 'Longing'
#  'Gloominess' 'Liveliness' 'Happiness' 'Surprise' 'Anticipation' 'Anger']
#
# SongID 563 | 74 participants
# Emotions: ['Dreamy' 'Gloominess' 'Fear' 'Longing' 'Relaxed' 'Calmness' 'Sadness'
#  'Anticipation' 'Inspiring' 'Joy' 'Surprise' 'Liveliness' 'Happiness']
#
# SongID 575 | 97 participants
# Emotions: ['Calmness' 'Dreamy' 'Sadness' 'Gloominess' 'Anticipation' 'Longing'
#  'Relaxed' 'Surprise' 'Happiness' 'Liveliness' 'Joy' 'Inspiring' 'Fear']
#
# SongID 128 | 93 participants
# Emotions: ['Longing' 'Calmness' 'Gloominess' 'Relaxed' 'Dreamy' 'Sadness'
#  'Happiness' 'Surprise' 'Anticipation' 'Inspiring' 'Joy' 'Liveliness']
#
# SongID 149 | 112 participants
# Emotions: ['Happiness' 'Joy' 'Longing' 'Anticipation' 'Relaxed' 'Calmness' 'Dreamy'
#  'Inspiring' 'Gloominess' 'Surprise' 'Liveliness' 'Anger' 'Fear' 'Sadness']
#
# SongID 187 | 49 participants
# Emotions: ['Calmness' 'Dreamy' 'Relaxed' 'Longing' 'Gloominess' 'Sadness'
#  'Anticipation' 'Fear' 'Inspiring']
#
# SongID 197 | 69 participants
# Emotions: ['Surprise' 'Anticipation' 'Gloominess' 'Liveliness' 'Anger' 'Inspiring'
#  'Joy' 'Relaxed' 'Calmness' 'Dreamy' 'Fear' 'Longing' 'Happiness'
#  'Sadness']
#
# SongID 318 | 74 participants
# Emotions: ['Surprise' 'Inspiring' 'Longing' 'Anticipation' 'Fear' 'Anger'
#  'Liveliness' 'Gloominess' 'Calmness' 'Sadness']
#
# SongID 514 | 65 participants
# Emotions: ['Anticipation' 'Liveliness' 'Longing' 'Inspiring' 'Anger' 'Joy' 'Fear'
#  'Surprise' 'Happiness' 'Relaxed']
#
# SongID 528 | 37 participants
# Emotions: ['Liveliness' 'Anger' 'Inspiring' 'Anticipation' 'Fear']
#
# SongID 536 | 75 participants
# Emotions: ['Liveliness' 'Joy' 'Happiness' 'Surprise' 'Relaxed' 'Gloominess'
#  'Longing' 'Inspiring' 'Dreamy' 'Calmness' 'Anger' 'Anticipation'
#  'Sadness']
#
# SongID 562 | 68 participants
# Emotions: ['Sadness' 'Anticipation' 'Gloominess' 'Liveliness' 'Joy' 'Happiness'
#  'Anger' 'Inspiring' 'Longing' 'Relaxed' 'Fear']
#
# SongID 136 | 113 participants
# Emotions: ['Gloominess' 'Dreamy' 'Calmness' 'Longing' 'Relaxed' 'Inspiring'
#  'Anticipation' 'Sadness' 'Fear' 'Joy' 'Happiness' 'Liveliness' 'Surprise'
#  'Anger']
#
# SongID 184 | 73 participants
# Emotions: ['Sadness' 'Calmness' 'Gloominess' 'Longing' 'Anticipation' 'Dreamy'
#  'Inspiring' 'Relaxed' 'Fear' 'Joy' 'Happiness']
#
# SongID 410 | 74 participants
# Emotions: ['Joy' 'Liveliness' 'Anticipation' 'Happiness' 'Inspiring' 'Relaxed'
#  'Surprise' 'Longing']
#
# SongID 502 | 58 participants
# Emotions: ['Liveliness' 'Anticipation' 'Anger' 'Fear' 'Surprise' 'Relaxed' 'Longing'
#  'Gloominess' 'Dreamy' 'Joy' 'Inspiring']
#
# SongID 526 | 94 participants
# Emotions: ['Joy' 'Happiness' 'Liveliness' 'Anticipation' 'Relaxed' 'Longing'
#  'Inspiring' 'Dreamy' 'Gloominess' 'Anger']
#
# SongID 557 | 46 participants
# Emotions: ['Joy' 'Happiness' 'Liveliness' 'Relaxed' 'Dreamy' 'Inspiring' 'Calmness'
#  'Gloominess' 'Longing' 'Anger' 'Fear' 'Anticipation']
#
# SongID 571 | 80 participants
# Emotions: ['Anger' 'Relaxed' 'Joy' 'Happiness' 'Liveliness' 'Surprise'
#  'Anticipation' 'Calmness' 'Dreamy' 'Inspiring' 'Gloominess' 'Longing'
#  'Fear']
#
# SongID 129 | 111 participants
# Emotions: ['Happiness' 'Relaxed' 'Calmness' 'Dreamy' 'Gloominess' 'Joy' 'Longing'
#  'Inspiring' 'Sadness' 'Anticipation' 'Liveliness' 'Surprise' 'Anger'
#  'Fear']
#
# SongID 195 | 45 participants
# Emotions: ['Gloominess' 'Fear' 'Anticipation' 'Anger' 'Longing' 'Inspiring'
#  'Sadness' 'Liveliness' 'Surprise']
#
# SongID 414 | 58 participants
# Emotions: ['Happiness' 'Relaxed' 'Joy' 'Liveliness' 'Inspiring']
#
# SongID 523 | 100 participants
# Emotions: ['Sadness' 'Fear' 'Gloominess' 'Longing' 'Anticipation' 'Dreamy'
#  'Liveliness' 'Inspiring' 'Happiness' 'Anger' 'Surprise' 'Joy' 'Relaxed'
#  'Calmness']
#
# SongID 547 | 86 participants
# Emotions: ['Sadness' 'Longing' 'Relaxed' 'Joy' 'Gloominess' 'Happiness' 'Dreamy'
#  'Calmness' 'Anticipation' 'Inspiring' 'Surprise' 'Liveliness']
#
# SongID 567 | 49 participants
# Emotions: ['Anger' 'Joy' 'Liveliness' 'Inspiring' 'Surprise' 'Relaxed'
#  'Anticipation' 'Dreamy' 'Fear' 'Gloominess' 'Calmness']
#
# SongID 568 | 81 participants
# Emotions: ['Anger' 'Joy' 'Longing' 'Liveliness' 'Anticipation' 'Dreamy' 'Fear'
#  'Inspiring' 'Happiness' 'Relaxed' 'Gloominess' 'Surprise']
#
# SongID 610 | 53 participants
# Emotions: ['Gloominess' 'Liveliness' 'Longing' 'Anticipation' 'Dreamy' 'Inspiring'
#  'Relaxed' 'Calmness' 'Surprise' 'Sadness' 'Anger']
#
# SongID 126 | 125 participants
# Emotions: ['Longing' 'Liveliness' 'Inspiring' 'Joy' 'Anticipation' 'Relaxed'
#  'Dreamy' 'Happiness' 'Calmness' 'Surprise' 'Gloominess' 'Sadness' 'Anger'
#  'Fear']
#
# SongID 406 | 128 participants
# Emotions: ['Longing' 'Relaxed' 'Inspiring' 'Calmness' 'Joy' 'Happiness' 'Liveliness'
#  'Sadness' 'Gloominess' 'Dreamy' 'Fear' 'Surprise' 'Anticipation' 'Anger']
#
# SongID 409 | 52 participants
# Emotions: ['Gloominess' 'Sadness' 'Longing' 'Joy' 'Calmness' 'Relaxed' 'Happiness'
#  'Liveliness' 'Surprise' 'Anticipation' 'Anger' 'Fear' 'Dreamy'
#  'Inspiring']
#
# SongID 569 | 72 participants
# Emotions: ['Relaxed' 'Happiness' 'Inspiring' 'Joy' 'Liveliness' 'Anticipation'
#  'Longing' 'Dreamy' 'Surprise' 'Anger' 'Fear']
#
# SongID 123 | 74 participants
# Emotions: ['Liveliness' 'Joy' 'Relaxed' 'Happiness' 'Calmness' 'Inspiring' 'Longing'
#  'Anticipation']
#
# SongID 158 | 60 participants
# Emotions: ['Anticipation' 'Relaxed' 'Calmness' 'Happiness' 'Longing' 'Dreamy'
#  'Inspiring' 'Fear' 'Sadness' 'Gloominess' 'Liveliness' 'Anger' 'Surprise']
#
# SongID 168 | 58 participants
# Emotions: ['Gloominess' 'Calmness' 'Anticipation' 'Fear' 'Surprise' 'Dreamy'
#  'Relaxed' 'Anger' 'Sadness' 'Longing' 'Inspiring']
#
# SongID 171 | 106 participants
# Emotions: ['Calmness' 'Joy' 'Happiness' 'Liveliness' 'Surprise' 'Anticipation'
#  'Inspiring' 'Relaxed' 'Longing' 'Dreamy']
#
# SongID 180 | 48 participants
# Emotions: ['Liveliness' 'Anticipation' 'Dreamy' 'Relaxed' 'Calmness' 'Gloominess'
#  'Surprise' 'Inspiring' 'Longing' 'Joy']
#
# SongID 267 | 59 participants
# Emotions: ['Liveliness' 'Anticipation' 'Joy' 'Happiness' 'Inspiring' 'Surprise'
#  'Longing' 'Anger']
#
# SongID 505 | 57 participants
# Emotions: ['Liveliness' 'Relaxed' 'Dreamy' 'Inspiring' 'Longing' 'Joy'
#  'Anticipation' 'Happiness' 'Anger']
#
# SongID 561 | 82 participants
# Emotions: ['Liveliness' 'Longing' 'Joy' 'Relaxed' 'Dreamy' 'Inspiring'
#  'Anticipation' 'Happiness' 'Gloominess' 'Surprise' 'Calmness' 'Sadness']
#
# SongID 203 | 89 participants
# Emotions: ['Liveliness' 'Relaxed' 'Happiness' 'Surprise' 'Anticipation' 'Calmness'
#  'Longing' 'Dreamy' 'Inspiring' 'Sadness' 'Gloominess' 'Joy']
#
# SongID 511 | 63 participants
# Emotions: ['Gloominess' 'Longing' 'Calmness' 'Relaxed' 'Liveliness' 'Dreamy' 'Anger'
#  'Anticipation' 'Fear' 'Joy' 'Inspiring' 'Sadness' 'Happiness']
#
# SongID 564 | 52 participants
# Emotions: ['Gloominess' 'Inspiring' 'Liveliness' 'Dreamy' 'Anger' 'Anticipation'
#  'Happiness' 'Longing' 'Sadness' 'Joy' 'Relaxed']
#
# SongID 578 | 77 participants
# Emotions: ['Joy' 'Longing' 'Liveliness' 'Anticipation' 'Inspiring' 'Dreamy'
#  'Surprise' 'Sadness' 'Relaxed' 'Calmness' 'Fear' 'Gloominess' 'Anger'
#  'Happiness']
#
# SongID 115 | 63 participants
# Emotions: ['Longing' 'Surprise' 'Calmness' 'Anticipation' 'Fear' 'Liveliness'
#  'Dreamy' 'Gloominess' 'Sadness' 'Inspiring' 'Relaxed' 'Anger']
#
# SongID 127 | 127 participants
# Emotions: ['Joy' 'Happiness' 'Liveliness' 'Relaxed' 'Calmness' 'Inspiring' 'Dreamy'
#  'Surprise' 'Longing' 'Anticipation' 'Sadness' 'Gloominess' 'Anger' 'Fear']
#
# SongID 148 | 79 participants
# Emotions: ['Calmness' 'Gloominess' 'Dreamy' 'Relaxed' 'Anticipation' 'Fear' 'Joy'
#  'Happiness' 'Surprise' 'Inspiring' 'Longing' 'Liveliness']
#
# SongID 205 | 103 participants
# Emotions: ['Liveliness' 'Anticipation' 'Relaxed' 'Joy' 'Surprise' 'Inspiring'
#  'Happiness' 'Dreamy' 'Gloominess' 'Calmness' 'Longing']
#
# SongID 574 | 78 participants
# Emotions: ['Relaxed' 'Calmness' 'Longing' 'Inspiring' 'Anticipation' 'Anger'
#  'Dreamy' 'Gloominess' 'Happiness' 'Joy' 'Sadness' 'Fear' 'Surprise']
#
# SongID 608 | 73 participants
# Emotions: ['Anticipation' 'Calmness' 'Dreamy' 'Inspiring' 'Liveliness' 'Surprise'
#  'Relaxed' 'Gloominess' 'Longing' 'Anger' 'Fear' 'Happiness']
#
# SongID 613 | 37 participants
# Emotions: ['Anticipation' 'Fear' 'Anger' 'Surprise' 'Gloominess' 'Longing']
#
# SongID 619 | 48 participants
# Emotions: ['Anticipation' 'Fear' 'Anger' 'Surprise' 'Inspiring' 'Liveliness'
#  'Gloominess' 'Happiness' 'Dreamy' 'Sadness' 'Longing' 'Calmness']
#
# SongID 534 | 58 participants
# Emotions: ['Gloominess' 'Longing' 'Sadness' 'Liveliness' 'Relaxed' 'Inspiring'
#  'Fear' 'Dreamy' 'Anger' 'Anticipation' 'Calmness' 'Surprise']
#
# SongID 556 | 79 participants
# Emotions: ['Liveliness' 'Anger' 'Anticipation' 'Longing' 'Relaxed' 'Happiness' 'Joy'
#  'Inspiring' 'Dreamy' 'Calmness' 'Gloominess' 'Sadness' 'Fear']
#
# SongID 573 | 105 participants
# Emotions: ['Joy' 'Longing' 'Dreamy' 'Happiness' 'Gloominess' 'Liveliness' 'Surprise'
#  'Relaxed' 'Calmness' 'Inspiring' 'Anticipation' 'Fear' 'Sadness']
#
# SongID 577 | 61 participants
# Emotions: ['Gloominess' 'Longing' 'Anticipation' 'Relaxed' 'Inspiring' 'Liveliness'
#  'Happiness' 'Joy' 'Calmness' 'Dreamy']
#
# SongID 107 | 108 participants
# Emotions: ['Liveliness' 'Anticipation' 'Dreamy' 'Anger' 'Fear' 'Inspiring'
#  'Surprise' 'Longing' 'Joy' 'Happiness' 'Sadness' 'Gloominess' 'Relaxed'
#  'Calmness']
#
# SongID 141 | 138 participants
# Emotions: ['Gloominess' 'Dreamy' 'Longing' 'Anticipation' 'Calmness' 'Joy'
#  'Inspiring' 'Relaxed' 'Happiness' 'Sadness' 'Liveliness' 'Surprise'
#  'Anger' 'Fear']
#
# SongID 177 | 67 participants
# Emotions: ['Liveliness' 'Calmness' 'Dreamy' 'Inspiring' 'Relaxed' 'Joy' 'Longing'
#  'Gloominess' 'Surprise' 'Anticipation' 'Happiness' 'Fear']
#
# SongID 544 | 85 participants
# Emotions: ['Anticipation' 'Liveliness' 'Sadness' 'Longing' 'Dreamy' 'Joy'
#  'Happiness' 'Relaxed' 'Inspiring' 'Gloominess' 'Surprise']
#
# SongID 548 | 59 participants
# Emotions: ['Relaxed' 'Inspiring' 'Calmness' 'Longing' 'Anticipation' 'Joy' 'Dreamy'
#  'Liveliness' 'Gloominess' 'Sadness']
#
# SongID 552 | 54 participants
# Emotions: ['Relaxed' 'Dreamy' 'Fear' 'Longing' 'Liveliness' 'Anticipation' 'Joy'
#  'Surprise' 'Inspiring' 'Sadness' 'Gloominess' 'Anger']
#
# SongID 553 | 95 participants
# Emotions: ['Gloominess' 'Dreamy' 'Longing' 'Liveliness' 'Inspiring' 'Sadness'
#  'Relaxed' 'Calmness' 'Happiness' 'Anticipation' 'Joy' 'Surprise' 'Anger'
#  'Fear']
#
# SongID 124 | 91 participants
# Emotions: ['Liveliness' 'Happiness' 'Relaxed' 'Dreamy' 'Anticipation' 'Inspiring'
#  'Joy' 'Gloominess' 'Surprise' 'Sadness' 'Calmness' 'Fear']
#
# SongID 530 | 79 participants
# Emotions: ['Inspiring' 'Longing' 'Liveliness' 'Relaxed' 'Dreamy' 'Joy' 'Gloominess'
#  'Happiness' 'Calmness' 'Anticipation']
#
# SongID 535 | 83 participants
# Emotions: ['Longing' 'Dreamy' 'Joy' 'Happiness' 'Relaxed' 'Calmness' 'Gloominess'
#  'Liveliness' 'Inspiring' 'Sadness' 'Surprise' 'Anticipation' 'Anger'
#  'Fear']
#
# SongID 570 | 79 participants
# Emotions: ['Liveliness' 'Happiness' 'Longing' 'Surprise' 'Anticipation' 'Inspiring'
#  'Joy' 'Dreamy' 'Sadness' 'Gloominess' 'Relaxed' 'Calmness']
#
# SongID 147 | 61 participants
# Emotions: ['Relaxed' 'Calmness' 'Dreamy' 'Gloominess' 'Happiness' 'Inspiring' 'Joy'
#  'Longing' 'Anticipation']
#
# SongID 398 | 93 participants
# Emotions: ['Longing' 'Calmness' 'Inspiring' 'Gloominess' 'Sadness' 'Anticipation'
#  'Dreamy' 'Joy' 'Relaxed' 'Fear' 'Surprise']
#
# SongID 506 | 104 participants
# Emotions: ['Longing' 'Dreamy' 'Liveliness' 'Happiness' 'Relaxed' 'Inspiring'
#  'Anticipation' 'Gloominess' 'Calmness' 'Joy' 'Sadness' 'Surprise' 'Anger'
#  'Fear']
#
# SongID 531 | 95 participants
# Emotions: ['Liveliness' 'Relaxed' 'Longing' 'Joy' 'Happiness' 'Anger' 'Inspiring'
#  'Anticipation' 'Gloominess' 'Calmness' 'Dreamy' 'Surprise']
#
# SongID 401 | 57 participants
# Emotions: ['Sadness' 'Fear' 'Liveliness' 'Joy' 'Happiness' 'Anticipation'
#  'Inspiring' 'Dreamy' 'Relaxed' 'Surprise']
#
# SongID 519 | 62 participants
# Emotions: ['Relaxed' 'Dreamy' 'Happiness' 'Longing' 'Calmness' 'Sadness'
#  'Anticipation' 'Gloominess' 'Surprise' 'Fear' 'Inspiring' 'Joy'
#  'Liveliness' 'Anger']
#
# SongID 541 | 84 participants
# Emotions: ['Longing' 'Anger' 'Joy' 'Liveliness' 'Anticipation' 'Sadness' 'Happiness'
#  'Dreamy' 'Gloominess' 'Relaxed' 'Inspiring' 'Surprise' 'Calmness' 'Fear']
#
# SongID 135 | 124 participants
# Emotions: ['Relaxed' 'Inspiring' 'Sadness' 'Gloominess' 'Longing' 'Dreamy'
#  'Anticipation' 'Surprise' 'Calmness' 'Fear' 'Joy' 'Happiness'
#  'Liveliness' 'Anger']
#
# SongID 201 | 69 participants
# Emotions: ['Relaxed' 'Calmness' 'Gloominess' 'Longing' 'Joy' 'Dreamy' 'Happiness'
#  'Liveliness' 'Surprise' 'Inspiring' 'Sadness' 'Anticipation']
#
# SongID 133 | 110 participants
# Emotions: ['Sadness' 'Gloominess' 'Relaxed' 'Calmness' 'Longing' 'Dreamy'
#  'Inspiring' 'Surprise' 'Anticipation' 'Fear' 'Happiness' 'Liveliness']
#
# SongID 166 | 66 participants
# Emotions: ['Anticipation' 'Inspiring' 'Fear' 'Sadness' 'Anger' 'Gloominess'
#  'Surprise' 'Dreamy' 'Relaxed']
#
# SongID 501 | 134 participants
# Emotions: ['Joy' 'Happiness' 'Relaxed' 'Calmness' 'Dreamy' 'Longing' 'Inspiring'
#  'Anticipation' 'Sadness' 'Gloominess']
#
# SongID 165 | 108 participants
# Emotions: ['Fear' 'Calmness' 'Dreamy' 'Sadness' 'Gloominess' 'Longing' 'Inspiring'
#  'Anticipation' 'Surprise' 'Relaxed' 'Liveliness' 'Anger']
#
# SongID 559 | 63 participants
# Emotions: ['Liveliness' 'Relaxed' 'Dreamy' 'Sadness' 'Anticipation' 'Inspiring'
#  'Joy' 'Longing' 'Calmness' 'Happiness' 'Gloominess']
#
# SongID 604 | 77 participants
# Emotions: ['Longing' 'Liveliness' 'Anticipation' 'Dreamy' 'Anger' 'Sadness'
#  'Gloominess' 'Joy' 'Inspiring' 'Surprise' 'Fear' 'Relaxed' 'Happiness'
#  'Calmness']
#
# SongID 285 | 80 participants
# Emotions: ['Anticipation' 'Gloominess' 'Calmness' 'Dreamy' 'Longing' 'Inspiring'
#  'Happiness' 'Liveliness' 'Relaxed' 'Surprise' 'Joy']
#
# SongID 419 | 79 participants
# Emotions: ['Happiness' 'Joy' 'Liveliness' 'Surprise' 'Relaxed' 'Anticipation'
#  'Sadness' 'Gloominess' 'Longing' 'Anger' 'Fear' 'Calmness' 'Dreamy'
#  'Inspiring']
#
# SongID 533 | 64 participants
# Emotions: ['Gloominess' 'Liveliness' 'Anticipation' 'Relaxed' 'Inspiring'
#  'Happiness' 'Joy' 'Dreamy' 'Calmness' 'Longing' 'Sadness' 'Anger'
#  'Surprise']
#
# SongID 601 | 73 participants
# Emotions: ['Longing' 'Liveliness' 'Joy' 'Happiness' 'Fear' 'Dreamy' 'Relaxed'
#  'Inspiring' 'Surprise' 'Anticipation' 'Anger' 'Sadness' 'Gloominess']
#
# SongID 198 | 73 participants
# Emotions: ['Gloominess' 'Fear' 'Anticipation' 'Relaxed' 'Dreamy' 'Happiness'
#  'Liveliness' 'Calmness' 'Inspiring' 'Longing' 'Surprise' 'Joy' 'Sadness']
#
# SongID 609 | 67 participants
# Emotions: ['Calmness' 'Anticipation' 'Inspiring' 'Fear' 'Gloominess' 'Surprise'
#  'Anger' 'Dreamy' 'Longing' 'Liveliness' 'Relaxed' 'Sadness']
#
# SongID 617 | 52 participants
# Emotions: ['Anger' 'Liveliness' 'Anticipation' 'Inspiring' 'Surprise' 'Fear'
#  'Gloominess' 'Calmness' 'Sadness' 'Joy']
#
# SongID 408 | 106 participants
# Emotions: ['Longing' 'Happiness' 'Relaxed' 'Liveliness' 'Calmness' 'Dreamy'
#  'Gloominess' 'Inspiring' 'Joy' 'Anger' 'Anticipation' 'Sadness' 'Fear'
#  'Surprise']
#
# SongID 509 | 102 participants
# Emotions: ['Relaxed' 'Happiness' 'Longing' 'Anticipation' 'Calmness' 'Dreamy'
#  'Inspiring' 'Liveliness' 'Joy' 'Gloominess']
#
# SongID 532 | 72 participants
# Emotions: ['Inspiring' 'Longing' 'Joy' 'Liveliness' 'Relaxed' 'Happiness'
#  'Anticipation' 'Gloominess' 'Fear' 'Anger']
#
# SongID 170 | 68 participants
# Emotions: ['Fear' 'Dreamy' 'Sadness' 'Anger' 'Gloominess' 'Relaxed' 'Surprise'
#  'Anticipation' 'Longing' 'Calmness' 'Inspiring']
#
# SongID 402 | 88 participants
# Emotions: ['Joy' 'Happiness' 'Liveliness' 'Relaxed' 'Inspiring' 'Longing' 'Anger'
#  'Surprise' 'Anticipation']
#
# SongID 580 | 78 participants
# Emotions: ['Relaxed' 'Calmness' 'Dreamy' 'Inspiring' 'Anticipation' 'Joy' 'Longing'
#  'Liveliness' 'Sadness' 'Happiness' 'Surprise' 'Gloominess']
#
# SongID 612 | 49 participants
# Emotions: ['Sadness' 'Longing' 'Anticipation' 'Liveliness' 'Inspiring' 'Gloominess'
#  'Relaxed' 'Calmness' 'Dreamy' 'Surprise' 'Fear' 'Happiness']
#
# SongID 173 | 113 participants
# Emotions: ['Liveliness' 'Relaxed' 'Inspiring' 'Anticipation' 'Longing' 'Anger'
#  'Fear' 'Happiness' 'Joy' 'Dreamy' 'Sadness' 'Calmness' 'Gloominess'
#  'Surprise']
#
# SongID 614 | 70 participants
# Emotions: ['Happiness' 'Relaxed' 'Surprise' 'Liveliness' 'Inspiring' 'Gloominess'
#  'Fear' 'Anticipation' 'Sadness' 'Longing' 'Dreamy' 'Anger' 'Joy'
#  'Calmness']
#
# SongID 620 | 52 participants
# Emotions: ['Liveliness' 'Anticipation' 'Gloominess' 'Fear' 'Anger' 'Joy' 'Dreamy'
#  'Inspiring' 'Happiness' 'Relaxed' 'Surprise' 'Longing' 'Sadness'
#  'Calmness']
#
# SongID 103 | 72 participants
# Emotions: ['Calmness' 'Anger' 'Sadness' 'Fear' 'Surprise' 'Liveliness'
#  'Anticipation' 'Longing' 'Inspiring' 'Relaxed' 'Joy']
#
# SongID 518 | 55 participants
# Emotions: ['Anticipation' 'Liveliness' 'Relaxed' 'Longing' 'Happiness' 'Dreamy'
#  'Joy' 'Surprise' 'Calmness' 'Inspiring']
#
# SongID 418 | 81 participants
# Emotions: ['Anticipation' 'Joy' 'Happiness' 'Liveliness' 'Inspiring' 'Relaxed'
#  'Calmness' 'Gloominess' 'Fear' 'Sadness' 'Longing' 'Dreamy' 'Surprise']
#
# SongID 516 | 94 participants
# Emotions: ['Joy' 'Liveliness' 'Relaxed' 'Calmness' 'Dreamy' 'Inspiring'
#  'Anticipation' 'Happiness' 'Longing']
#
# SongID 538 | 71 participants
# Emotions: ['Liveliness' 'Dreamy' 'Happiness' 'Relaxed' 'Anticipation' 'Calmness'
#  'Gloominess' 'Inspiring' 'Sadness' 'Longing' 'Joy']
#
# SongID 121 | 121 participants
# Emotions: ['Happiness' 'Liveliness' 'Relaxed' 'Dreamy' 'Inspiring' 'Joy'
#  'Anticipation' 'Longing' 'Calmness' 'Surprise' 'Gloominess' 'Anger'
#  'Fear']
#
# SongID 162 | 60 participants
# Emotions: ['Gloominess' 'Anticipation' 'Sadness' 'Longing' 'Anger' 'Fear' 'Surprise'
#  'Inspiring' 'Relaxed' 'Dreamy' 'Calmness']
#
# SongID 221 | 65 participants
# Emotions: ['Gloominess' 'Longing' 'Fear' 'Anger' 'Anticipation' 'Inspiring'
#  'Sadness' 'Surprise' 'Liveliness' 'Relaxed']
#
# SongID 347 | 63 participants
# Emotions: ['Joy' 'Happiness' 'Liveliness' 'Relaxed' 'Anticipation' 'Dreamy'
#  'Inspiring' 'Calmness' 'Anger' 'Surprise']
#
# SongID 412 | 51 participants
# Emotions: ['Gloominess' 'Longing' 'Inspiring' 'Relaxed' 'Calmness' 'Dreamy'
#  'Sadness' 'Joy' 'Liveliness' 'Anger' 'Anticipation']
#
# SongID 521 | 98 participants
# Emotions: ['Liveliness' 'Anticipation' 'Longing' 'Dreamy' 'Inspiring' 'Relaxed'
#  'Calmness' 'Happiness' 'Gloominess' 'Surprise' 'Joy' 'Anger' 'Fear']
#
# SongID 576 | 68 participants
# Emotions: ['Joy' 'Happiness' 'Liveliness' 'Dreamy' 'Inspiring' 'Anticipation'
#  'Relaxed' 'Calmness' 'Anger' 'Gloominess' 'Longing']
#
# SongID 560 | 65 participants
# Emotions: ['Joy' 'Liveliness' 'Anticipation' 'Gloominess' 'Inspiring' 'Dreamy'
#  'Longing' 'Relaxed' 'Sadness' 'Calmness' 'Surprise' 'Happiness' 'Anger']
#
# SongID 416 | 79 participants
# Emotions: ['Joy' 'Liveliness' 'Gloominess' 'Anticipation' 'Relaxed' 'Calmness'
#  'Dreamy' 'Inspiring' 'Happiness' 'Sadness' 'Longing' 'Surprise']
#
# SongID 508 | 53 participants
# Emotions: ['Joy' 'Happiness' 'Liveliness' 'Surprise' 'Inspiring' 'Anticipation'
#  'Relaxed' 'Calmness' 'Sadness' 'Anger' 'Fear' 'Dreamy' 'Longing']
#
# SongID 294 | 67 participants
# Emotions: ['Gloominess' 'Happiness' 'Anticipation' 'Relaxed' 'Calmness' 'Dreamy'
#  'Sadness' 'Longing' 'Fear' 'Inspiring' 'Joy' 'Surprise']
#
# SongID 527 | 44 participants
# Emotions: ['Sadness' 'Relaxed' 'Liveliness' 'Anticipation' 'Calmness' 'Longing'
#  'Inspiring' 'Dreamy' 'Gloominess' 'Joy']
#
# SongID 113 | 63 participants
# Emotions: ['Anticipation' 'Inspiring' 'Surprise' 'Fear' 'Relaxed' 'Liveliness'
#  'Anger' 'Dreamy' 'Longing' 'Calmness']
#
# SongID 413 | 59 participants
# Emotions: ['Anticipation' 'Joy' 'Liveliness' 'Relaxed' 'Inspiring' 'Longing' 'Fear'
#  'Gloominess' 'Sadness' 'Surprise' 'Calmness' 'Dreamy' 'Anger' 'Happiness']
#
# SongID 546 | 50 participants
# Emotions: ['Anger' 'Liveliness' 'Anticipation' 'Fear' 'Joy' 'Inspiring' 'Longing'
#  'Surprise' 'Gloominess' 'Relaxed' 'Happiness' 'Dreamy']
#
# SongID 550 | 75 participants
# Emotions: ['Anger' 'Relaxed' 'Dreamy' 'Sadness' 'Longing' 'Calmness' 'Gloominess'
#  'Anticipation' 'Liveliness' 'Inspiring' 'Joy']
#
# SongID 517 | 79 participants
# Emotions: ['Joy' 'Liveliness' 'Inspiring' 'Happiness' 'Relaxed' 'Surprise'
#  'Calmness' 'Dreamy' 'Anticipation']
#
# SongID 579 | 50 participants
# Emotions: ['Liveliness' 'Longing' 'Joy' 'Anticipation' 'Inspiring' 'Happiness'
#  'Gloominess' 'Relaxed' 'Dreamy' 'Anger']
#
# SongID 142 | 115 participants
# Emotions: ['Sadness' 'Gloominess' 'Relaxed' 'Calmness' 'Dreamy' 'Inspiring' 'Joy'
#  'Liveliness' 'Happiness' 'Longing' 'Surprise' 'Anticipation']
#
# SongID 145 | 68 participants
# Emotions: ['Relaxed' 'Calmness' 'Longing' 'Dreamy' 'Anticipation' 'Happiness'
#  'Inspiring' 'Sadness' 'Gloominess' 'Joy']
#
# SongID 152 | 96 participants
# Emotions: ['Gloominess' 'Longing' 'Relaxed' 'Calmness' 'Dreamy' 'Joy' 'Anticipation'
#  'Inspiring' 'Happiness' 'Sadness' 'Surprise' 'Liveliness']
#
# SongID 140 | 104 participants
# Emotions: ['Sadness' 'Gloominess' 'Longing' 'Inspiring' 'Relaxed' 'Calmness'
#  'Dreamy' 'Anticipation' 'Joy' 'Liveliness' 'Surprise' 'Anger' 'Fear'
#  'Happiness']
#
# SongID 540 | 54 participants
# Emotions: ['Sadness' 'Anger' 'Liveliness' 'Longing' 'Surprise' 'Anticipation' 'Fear'
#  'Inspiring' 'Joy']
#
# SongID 602 | 79 participants
# Emotions: ['Anticipation' 'Inspiring' 'Calmness' 'Sadness' 'Gloominess' 'Relaxed'
#  'Dreamy' 'Joy' 'Happiness' 'Surprise' 'Longing' 'Anger' 'Fear']
#
# SongID 169 | 68 participants
# Emotions: ['Anticipation' 'Inspiring' 'Surprise' 'Fear' 'Anger' 'Sadness' 'Dreamy'
#  'Gloominess']
#
# SongID 208 | 71 participants
# Emotions: ['Dreamy' 'Calmness' 'Gloominess' 'Longing' 'Relaxed' 'Sadness'
#  'Anticipation' 'Happiness' 'Joy' 'Liveliness' 'Surprise' 'Anger' 'Fear'
#  'Inspiring']
#
# SongID 507 | 94 participants
# Emotions: ['Sadness' 'Longing' 'Happiness' 'Relaxed' 'Calmness' 'Gloominess'
#  'Dreamy' 'Anticipation' 'Anger' 'Liveliness' 'Fear' 'Inspiring' 'Joy']
#
# SongID 202 | 47 participants
# Emotions: ['Gloominess' 'Longing' 'Relaxed' 'Calmness' 'Dreamy' 'Inspiring'
#  'Liveliness' 'Anticipation' 'Joy' 'Sadness' 'Surprise']
#
# SongID 207 | 54 participants
# Emotions: ['Dreamy' 'Gloominess' 'Sadness' 'Surprise' 'Calmness' 'Relaxed' 'Longing'
#  'Anticipation' 'Inspiring' 'Happiness' 'Joy']
#
# SongID 554 | 66 participants
# Emotions: ['Longing' 'Liveliness' 'Dreamy' 'Joy' 'Happiness' 'Inspiring' 'Relaxed'
#  'Anticipation' 'Gloominess' 'Calmness']
#
# SongID 606 | 85 participants
# Emotions: ['Anticipation' 'Fear' 'Anger' 'Gloominess' 'Surprise' 'Calmness'
#  'Sadness' 'Longing' 'Dreamy' 'Joy' 'Happiness' 'Liveliness' 'Relaxed'
#  'Inspiring']
#
# SongID 188 | 82 participants
# Emotions: ['Calmness' 'Dreamy' 'Anticipation' 'Sadness' 'Gloominess' 'Relaxed'
#  'Inspiring' 'Fear' 'Longing']
#
# SongID 139 | 97 participants
# Emotions: ['Longing' 'Dreamy' 'Inspiring' 'Relaxed' 'Calmness' 'Anticipation'
#  'Sadness' 'Joy' 'Happiness' 'Liveliness' 'Gloominess' 'Surprise']
#
# SongID 143 | 116 participants
# Emotions: ['Gloominess' 'Longing' 'Joy' 'Relaxed' 'Calmness' 'Happiness' 'Dreamy'
#  'Inspiring' 'Liveliness' 'Anticipation' 'Sadness']
#
# SongID 157 | 83 participants
# Emotions: ['Joy' 'Liveliness' 'Anticipation' 'Inspiring' 'Happiness' 'Relaxed'
#  'Calmness' 'Longing' 'Surprise' 'Dreamy' 'Sadness']
#
# SongID 566 | 73 participants
# Emotions: ['Inspiring' 'Joy' 'Longing' 'Happiness' 'Liveliness' 'Relaxed' 'Calmness'
#  'Surprise' 'Anger' 'Sadness' 'Gloominess' 'Anticipation' 'Dreamy']
#
# SongID 110 | 78 participants
# Emotions: ['Anticipation' 'Fear' 'Longing' 'Surprise' 'Relaxed' 'Dreamy' 'Inspiring'
#  'Anger' 'Calmness' 'Gloominess' 'Sadness']
#
# SongID 210 | 76 participants
# Emotions: ['Relaxed' 'Calmness' 'Dreamy' 'Inspiring' 'Joy' 'Happiness' 'Longing'
#  'Anticipation' 'Surprise' 'Sadness' 'Gloominess']
#
# SongID 510 | 71 participants
# Emotions: ['Liveliness' 'Inspiring' 'Joy' 'Surprise' 'Relaxed' 'Happiness' 'Dreamy'
#  'Sadness' 'Gloominess' 'Longing' 'Anticipation' 'Anger' 'Fear' 'Calmness']
#
# SongID 522 | 81 participants
# Emotions: ['Relaxed' 'Liveliness' 'Anticipation' 'Calmness' 'Dreamy' 'Surprise'
#  'Joy' 'Inspiring' 'Happiness' 'Sadness' 'Gloominess' 'Longing' 'Anger'
#  'Fear']
#
# SongID 524 | 93 participants
# Emotions: ['Relaxed' 'Gloominess' 'Dreamy' 'Anticipation' 'Inspiring' 'Calmness'
#  'Joy' 'Happiness' 'Sadness' 'Longing' 'Liveliness' 'Surprise' 'Anger'
#  'Fear']
#
# SongID 407 | 61 participants
# Emotions: ['Gloominess' 'Joy' 'Happiness' 'Anticipation' 'Relaxed' 'Inspiring'
#  'Sadness' 'Longing' 'Calmness' 'Dreamy' 'Anger' 'Fear' 'Liveliness']
#
# SongID 603 | 81 participants
# Emotions: ['Surprise' 'Anticipation' 'Inspiring' 'Liveliness' 'Longing' 'Fear'
#  'Gloominess' 'Relaxed' 'Calmness' 'Dreamy' 'Joy']
#
# SongID 132 | 74 participants
# Emotions: ['Gloominess' 'Sadness' 'Anticipation' 'Longing' 'Calmness' 'Dreamy'
#  'Surprise' 'Fear' 'Relaxed' 'Inspiring']
#
# SongID 154 | 54 participants
# Emotions: ['Gloominess' 'Dreamy' 'Inspiring' 'Calmness' 'Longing' 'Anticipation'
#  'Relaxed' 'Fear' 'Liveliness']
#
# SongID 194 | 65 participants
# Emotions: ['Anger' 'Fear' 'Anticipation' 'Longing' 'Sadness' 'Gloominess' 'Surprise'
#  'Calmness' 'Inspiring' 'Liveliness']
#
# SongID 549 | 71 participants
# Emotions: ['Gloominess' 'Longing' 'Liveliness' 'Anticipation' 'Joy' 'Relaxed'
#  'Anger' 'Sadness' 'Dreamy' 'Inspiring' 'Calmness' 'Surprise' 'Fear'
#  'Happiness']
#
# SongID 512 | 41 participants
# Emotions: ['Liveliness' 'Inspiring' 'Surprise' 'Anger' 'Fear' 'Sadness' 'Longing'
#  'Anticipation' 'Dreamy']
#
# SongID 411 | 67 participants
# Emotions: ['Sadness' 'Gloominess' 'Fear' 'Happiness' 'Relaxed' 'Calmness' 'Longing'
#  'Anticipation' 'Joy' 'Liveliness' 'Inspiring' 'Dreamy']
#
# SongID 543 | 70 participants
# Emotions: ['Anticipation' 'Liveliness' 'Inspiring' 'Joy' 'Happiness' 'Relaxed'
#  'Surprise' 'Sadness' 'Gloominess' 'Longing' 'Anger' 'Fear' 'Calmness'
#  'Dreamy']
#
# SongID 403 | 124 participants
# Emotions: ['Anticipation' 'Gloominess' 'Longing' 'Dreamy' 'Sadness' 'Fear'
#  'Calmness' 'Joy' 'Liveliness' 'Relaxed' 'Inspiring' 'Happiness'
#  'Surprise' 'Anger']
#
# SongID 199 | 50 participants
# Emotions: ['Dreamy' 'Longing' 'Anticipation' 'Fear' 'Sadness' 'Gloominess' 'Anger'
#  'Inspiring' 'Surprise' 'Calmness']
#
# SongID 611 | 64 participants
# Emotions: ['Dreamy' 'Liveliness' 'Surprise' 'Anticipation' 'Fear' 'Inspiring'
#  'Happiness' 'Joy' 'Sadness' 'Gloominess' 'Longing' 'Anger' 'Relaxed'
#  'Calmness']
#
# SongID 256 | 84 participants
# Emotions: ['Sadness' 'Fear' 'Inspiring' 'Anticipation' 'Joy' 'Liveliness' 'Surprise'
#  'Relaxed' 'Calmness' 'Longing' 'Dreamy' 'Happiness' 'Gloominess' 'Anger']
#
# SongID 558 | 97 participants
# Emotions: ['Sadness' 'Gloominess' 'Longing' 'Dreamy' 'Joy' 'Happiness'
#  'Anticipation' 'Surprise' 'Relaxed' 'Liveliness' 'Inspiring' 'Calmness']
#
# SongID 405 | 77 participants
# Emotions: ['Sadness' 'Gloominess' 'Calmness' 'Dreamy' 'Happiness' 'Longing'
#  'Inspiring' 'Joy' 'Anticipation' 'Liveliness' 'Anger' 'Fear' 'Relaxed']
#
# SongID 545 | 54 participants
# Emotions: ['Anticipation' 'Liveliness' 'Inspiring' 'Relaxed' 'Gloominess' 'Joy'
#  'Dreamy' 'Happiness' 'Surprise' 'Longing' 'Calmness']

# %%
encoder = LabelEncoder()
encoder.fit(emotions)
df["EmotionEncoded"] = encoder.transform(df["Emotion"])
emotion_mapping = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))

print([f'{k}: {v}' for k, v in emotion_mapping.items()])
print(df.shape, df.columns)
# Out:
# ['Anger: 0', 'Anticipation: 1', 'Calmness: 2', 'Dreamy: 3', 'Fear: 4', 'Gloominess: 5', 'Happiness: 6', 'Inspiring: 7', 'Joy: 8', 'Liveliness: 9', 'Longing: 10', 'Relaxed: 11', 'Sadness: 12', 'Surprise: 13']
# (15212, 8) Index(['SongID', 'H', 'S', 'V', 'Val', 'Ar', 'Emotion', 'EmotionEncoded'], dtype='object')

# %%
feature_dir = "../../../moodo/audio_features2"

update_rows = []
for i, filename in enumerate(os.listdir(feature_dir)):
    print(f'{i}/{len(os.listdir(feature_dir))}', end='\r')
    
    song_id = filename.split('.')[0]
    file_path = os.path.join(feature_dir, filename)

    # shape: (n_segments, 13, 216)
    feature_matrix = np.load(file_path)
    n_segment = feature_matrix.shape[0]
    
    songs = df[df['SongID'] == song_id]
    
    # for every row with the same song_id, duplicate the row n_segment times and add each segment's features
    for _, song in songs.iterrows():
        for segment in feature_matrix:
            row = np.hstack([segment.flatten(), song.values])
            update_rows.append(row)

dataset = np.array(update_rows)
print(dataset.shape) # 13x216 = 2808   + 8 (targets) = 2816
# Out:
# (76034, 2816)

# %%
# double checking dimensions make sense
total_rows = 0
x=0
with open('../../../moodo/indices.txt', 'w') as file:
    for song_id in df['SongID'].unique():
        song = df[df['SongID'] == song_id]
        
        emotions_listed = song['Emotion'].unique()
        n_participants = len(song)
        
        file_path = os.path.join(feature_dir, f'{song_id}.npy')

        # shape: (n_segments, 13, 216)
        feature_matrix = np.load(file_path)
        n_segment = feature_matrix.shape[0]
        
        n_rows = n_participants*n_segment
        total_rows += n_rows
        print(f'SongID {song_id} | {n_rows} rows | indices: {x}:{x+n_rows}')
        file.write(f'{song_id},{n_rows},{x},{x+n_rows}\n')
        x += n_rows

print(f'Total rows: {total_rows}')
# Out:
# SongID 101 | 200 rows | indices: 0:200
# SongID 153 | 415 rows | indices: 200:615
# SongID 209 | 180 rows | indices: 615:795
# SongID 242 | 592 rows | indices: 795:1387
# SongID 504 | 315 rows | indices: 1387:1702
# SongID 513 | 470 rows | indices: 1702:2172
# SongID 525 | 475 rows | indices: 2172:2647
# SongID 551 | 450 rows | indices: 2647:3097
# SongID 607 | 240 rows | indices: 3097:3337
# SongID 618 | 230 rows | indices: 3337:3567
# SongID 104 | 440 rows | indices: 3567:4007
# SongID 172 | 336 rows | indices: 4007:4343
# SongID 204 | 685 rows | indices: 4343:5028
# SongID 367 | 190 rows | indices: 5028:5218
# SongID 503 | 365 rows | indices: 5218:5583
# SongID 555 | 255 rows | indices: 5583:5838
# SongID 565 | 390 rows | indices: 5838:6228
# SongID 109 | 464 rows | indices: 6228:6692
# SongID 155 | 296 rows | indices: 6692:6988
# SongID 156 | 456 rows | indices: 6988:7444
# SongID 181 | 192 rows | indices: 7444:7636
# SongID 190 | 340 rows | indices: 7636:7976
# SongID 196 | 350 rows | indices: 7976:8326
# SongID 404 | 225 rows | indices: 8326:8551
# SongID 539 | 355 rows | indices: 8551:8906
# SongID 615 | 240 rows | indices: 8906:9146
# SongID 130 | 455 rows | indices: 9146:9601
# SongID 161 | 435 rows | indices: 9601:10036
# SongID 415 | 280 rows | indices: 10036:10316
# SongID 417 | 395 rows | indices: 10316:10711
# SongID 529 | 530 rows | indices: 10711:11241
# SongID 537 | 310 rows | indices: 11241:11551
# SongID 572 | 475 rows | indices: 11551:12026
# SongID 605 | 380 rows | indices: 12026:12406
# SongID 616 | 240 rows | indices: 12406:12646
# SongID 164 | 545 rows | indices: 12646:13191
# SongID 186 | 295 rows | indices: 13191:13486
# SongID 420 | 360 rows | indices: 13486:13846
# SongID 515 | 595 rows | indices: 13846:14441
# SongID 520 | 385 rows | indices: 14441:14826
# SongID 542 | 430 rows | indices: 14826:15256
# SongID 563 | 370 rows | indices: 15256:15626
# SongID 575 | 485 rows | indices: 15626:16111
# SongID 128 | 465 rows | indices: 16111:16576
# SongID 149 | 560 rows | indices: 16576:17136
# SongID 187 | 245 rows | indices: 17136:17381
# SongID 197 | 345 rows | indices: 17381:17726
# SongID 318 | 370 rows | indices: 17726:18096
# SongID 514 | 260 rows | indices: 18096:18356
# SongID 528 | 185 rows | indices: 18356:18541
# SongID 536 | 375 rows | indices: 18541:18916
# SongID 562 | 340 rows | indices: 18916:19256
# SongID 136 | 565 rows | indices: 19256:19821
# SongID 184 | 365 rows | indices: 19821:20186
# SongID 410 | 370 rows | indices: 20186:20556
# SongID 502 | 290 rows | indices: 20556:20846
# SongID 526 | 470 rows | indices: 20846:21316
# SongID 557 | 230 rows | indices: 21316:21546
# SongID 571 | 400 rows | indices: 21546:21946
# SongID 129 | 777 rows | indices: 21946:22723
# SongID 195 | 225 rows | indices: 22723:22948
# SongID 414 | 290 rows | indices: 22948:23238
# SongID 523 | 500 rows | indices: 23238:23738
# SongID 547 | 430 rows | indices: 23738:24168
# SongID 567 | 245 rows | indices: 24168:24413
# SongID 568 | 405 rows | indices: 24413:24818
# SongID 610 | 265 rows | indices: 24818:25083
# SongID 126 | 625 rows | indices: 25083:25708
# SongID 406 | 640 rows | indices: 25708:26348
# SongID 409 | 260 rows | indices: 26348:26608
# SongID 569 | 360 rows | indices: 26608:26968
# SongID 123 | 296 rows | indices: 26968:27264
# SongID 158 | 300 rows | indices: 27264:27564
# SongID 168 | 290 rows | indices: 27564:27854
# SongID 171 | 530 rows | indices: 27854:28384
# SongID 180 | 192 rows | indices: 28384:28576
# SongID 267 | 295 rows | indices: 28576:28871
# SongID 505 | 228 rows | indices: 28871:29099
# SongID 561 | 410 rows | indices: 29099:29509
# SongID 203 | 445 rows | indices: 29509:29954
# SongID 511 | 315 rows | indices: 29954:30269
# SongID 564 | 260 rows | indices: 30269:30529
# SongID 578 | 385 rows | indices: 30529:30914
# SongID 115 | 252 rows | indices: 30914:31166
# SongID 127 | 1016 rows | indices: 31166:32182
# SongID 148 | 316 rows | indices: 32182:32498
# SongID 205 | 515 rows | indices: 32498:33013
# SongID 574 | 390 rows | indices: 33013:33403
# SongID 608 | 365 rows | indices: 33403:33768
# SongID 613 | 185 rows | indices: 33768:33953
# SongID 619 | 240 rows | indices: 33953:34193
# SongID 534 | 290 rows | indices: 34193:34483
# SongID 556 | 395 rows | indices: 34483:34878
# SongID 573 | 525 rows | indices: 34878:35403
# SongID 577 | 305 rows | indices: 35403:35708
# SongID 107 | 540 rows | indices: 35708:36248
# SongID 141 | 690 rows | indices: 36248:36938
# SongID 177 | 335 rows | indices: 36938:37273
# SongID 544 | 425 rows | indices: 37273:37698
# SongID 548 | 295 rows | indices: 37698:37993
# SongID 552 | 270 rows | indices: 37993:38263
# SongID 553 | 475 rows | indices: 38263:38738
# SongID 124 | 364 rows | indices: 38738:39102
# SongID 530 | 395 rows | indices: 39102:39497
# SongID 535 | 415 rows | indices: 39497:39912
# SongID 570 | 395 rows | indices: 39912:40307
# SongID 147 | 305 rows | indices: 40307:40612
# SongID 398 | 465 rows | indices: 40612:41077
# SongID 506 | 520 rows | indices: 41077:41597
# SongID 531 | 475 rows | indices: 41597:42072
# SongID 401 | 285 rows | indices: 42072:42357
# SongID 519 | 248 rows | indices: 42357:42605
# SongID 541 | 420 rows | indices: 42605:43025
# SongID 135 | 620 rows | indices: 43025:43645
# SongID 201 | 345 rows | indices: 43645:43990
# SongID 133 | 550 rows | indices: 43990:44540
# SongID 166 | 330 rows | indices: 44540:44870
# SongID 501 | 670 rows | indices: 44870:45540
# SongID 165 | 540 rows | indices: 45540:46080
# SongID 559 | 315 rows | indices: 46080:46395
# SongID 604 | 385 rows | indices: 46395:46780
# SongID 285 | 480 rows | indices: 46780:47260
# SongID 419 | 395 rows | indices: 47260:47655
# SongID 533 | 320 rows | indices: 47655:47975
# SongID 601 | 365 rows | indices: 47975:48340
# SongID 198 | 365 rows | indices: 48340:48705
# SongID 609 | 335 rows | indices: 48705:49040
# SongID 617 | 260 rows | indices: 49040:49300
# SongID 408 | 530 rows | indices: 49300:49830
# SongID 509 | 510 rows | indices: 49830:50340
# SongID 532 | 360 rows | indices: 50340:50700
# SongID 170 | 340 rows | indices: 50700:51040
# SongID 402 | 440 rows | indices: 51040:51480
# SongID 580 | 390 rows | indices: 51480:51870
# SongID 612 | 245 rows | indices: 51870:52115
# SongID 173 | 565 rows | indices: 52115:52680
# SongID 614 | 350 rows | indices: 52680:53030
# SongID 620 | 260 rows | indices: 53030:53290
# SongID 103 | 360 rows | indices: 53290:53650
# SongID 518 | 275 rows | indices: 53650:53925
# SongID 418 | 405 rows | indices: 53925:54330
# SongID 516 | 470 rows | indices: 54330:54800
# SongID 538 | 355 rows | indices: 54800:55155
# SongID 121 | 605 rows | indices: 55155:55760
# SongID 162 | 300 rows | indices: 55760:56060
# SongID 221 | 325 rows | indices: 56060:56385
# SongID 347 | 315 rows | indices: 56385:56700
# SongID 412 | 255 rows | indices: 56700:56955
# SongID 521 | 490 rows | indices: 56955:57445
# SongID 576 | 340 rows | indices: 57445:57785
# SongID 560 | 325 rows | indices: 57785:58110
# SongID 416 | 395 rows | indices: 58110:58505
# SongID 508 | 265 rows | indices: 58505:58770
# SongID 294 | 335 rows | indices: 58770:59105
# SongID 527 | 220 rows | indices: 59105:59325
# SongID 113 | 315 rows | indices: 59325:59640
# SongID 413 | 295 rows | indices: 59640:59935
# SongID 546 | 250 rows | indices: 59935:60185
# SongID 550 | 375 rows | indices: 60185:60560
# SongID 517 | 395 rows | indices: 60560:60955
# SongID 579 | 250 rows | indices: 60955:61205
# SongID 142 | 575 rows | indices: 61205:61780
# SongID 145 | 340 rows | indices: 61780:62120
# SongID 152 | 384 rows | indices: 62120:62504
# SongID 140 | 520 rows | indices: 62504:63024
# SongID 540 | 270 rows | indices: 63024:63294
# SongID 602 | 395 rows | indices: 63294:63689
# SongID 169 | 340 rows | indices: 63689:64029
# SongID 208 | 355 rows | indices: 64029:64384
# SongID 507 | 470 rows | indices: 64384:64854
# SongID 202 | 235 rows | indices: 64854:65089
# SongID 207 | 270 rows | indices: 65089:65359
# SongID 554 | 330 rows | indices: 65359:65689
# SongID 606 | 425 rows | indices: 65689:66114
# SongID 188 | 410 rows | indices: 66114:66524
# SongID 139 | 485 rows | indices: 66524:67009
# SongID 143 | 580 rows | indices: 67009:67589
# SongID 157 | 415 rows | indices: 67589:68004
# SongID 566 | 365 rows | indices: 68004:68369
# SongID 110 | 390 rows | indices: 68369:68759
# SongID 210 | 380 rows | indices: 68759:69139
# SongID 510 | 355 rows | indices: 69139:69494
# SongID 522 | 405 rows | indices: 69494:69899
# SongID 524 | 465 rows | indices: 69899:70364
# SongID 407 | 305 rows | indices: 70364:70669
# SongID 603 | 405 rows | indices: 70669:71074
# SongID 132 | 370 rows | indices: 71074:71444
# SongID 154 | 270 rows | indices: 71444:71714
# SongID 194 | 325 rows | indices: 71714:72039
# SongID 549 | 355 rows | indices: 72039:72394
# SongID 512 | 205 rows | indices: 72394:72599
# SongID 411 | 335 rows | indices: 72599:72934
# SongID 543 | 350 rows | indices: 72934:73284
# SongID 403 | 620 rows | indices: 73284:73904
# SongID 199 | 250 rows | indices: 73904:74154
# SongID 611 | 320 rows | indices: 74154:74474
# SongID 256 | 420 rows | indices: 74474:74894
# SongID 558 | 485 rows | indices: 74894:75379
# SongID 405 | 385 rows | indices: 75379:75764
# SongID 545 | 270 rows | indices: 75764:76034
# Total rows: 76034

# %%
# write indices to a text file
with open('../../../moodo/indices.txt', 'w') as file:
    for song_id in df['SongID'].unique():
        song = df[df['SongID'] == song_id]

        emotions_listed = song['Emotion'].unique()
        n_participants = len(song)

        file_path = os.path.join(feature_dir, f'{song_id}.npy')

        # shape: (n_segments, 13, 216)
        feature_matrix = np.load(file_path)
        n_segment = feature_matrix.shape[0]

        n_rows = n_participants*n_segment
        file.write(f'{song_id} {n_rows}\n')

# %%
with open('../../../moodo/dataset2.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    
    # columns: 0:2808 -> features, 2808:2816 -> targets
    writer.writerows(dataset)
