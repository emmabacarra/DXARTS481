# %% [markdown]
# Songs - The participant's mood/color/emotion perception of songs
#     SongID - ID (also filename) of song in our dataset
#     Perceived - A list of emotions which the song perceived by the participant
#         V, A - The position of the chosen perceived emotion in the valence-arousal space [0,1]
#     SongColor - The participant's choice of best-matching color of a song in the HSV space (H - hue [0-1], S - saturation [0-1], V -value [0-1])
#
#
# convert mp4 audio to delta capstrum feature vector?
#
# input: dcf vector --> array of vectors
#
# test/output: perceivedVA, songcolor --> sort by song_id (rows), columns will be HSV color values

# %%
from bs4 import BeautifulSoup
import os
import librosa
import numpy as np
from collections import defaultdict
import csv

# %%
def extract_features(file_path, sr=22050, duration=5.0, hop_size=2.5):
    """
    Extracts delta cepstrum features using a sliding window approach.
    :param file_path: Path to the audio file.
    :param sr: Sampling rate.
    :param duration: Fixed length of each segment (seconds).
    :param hop_size: Overlapping step size between segments (seconds).
    :return: A list of feature arrays.
    """
    y, _ = librosa.load(file_path, sr=sr)
    segment_length = int(sr * duration)
    hop_length = int(sr * hop_size)

    features = []
    
    # Iterate over the audio in sliding windows
    for start in range(0, len(y) - segment_length + 1, hop_length):
        y_segment = y[start:start + segment_length]
        
        mfcc = librosa.feature.mfcc(y=y_segment, sr=sr, n_mfcc=13) # mel-frequency cepstrum features
        dcf = librosa.feature.delta(mfcc) # delta cepstrum features

        features.append(dcf)

    return np.array(features)

# %%
n_songs = len(os.listdir('../../../moodo/audio'))
for i, file in enumerate(os.listdir('../../../moodo/audio'), 1):
    
    song_id = file.split('.')[0]
    file_path = os.path.join('../../../moodo/audio', file)
    
    features = extract_features(file_path)
    
    os.makedirs('../../../moodo/audio_features2', exist_ok=True)
    
    np.save(f'../../../moodo/audio_features2/{song_id}.npy', features)
    print(f'Saved {i}/{n_songs} songs           ', end='\r')
# Out:
# Saved 200/200 songs

# %%
with open('../../../moodo/dataset.xml', 'r') as file:
    soup = BeautifulSoup(file, 'xml')
    
hsv_values = defaultdict(list)
perceived_emotions = defaultdict(list)

for item in soup.find_all('item'):
    for song in item.find_all('Songs'):
        for song_item in song.find_all('item'):
            song_id = song_item.find('SongID').text
            song_color = song_item.find('SongColor')
            
            h = float(song_color.find('H').text)
            s = float(song_color.find('S').text)
            v = float(song_color.find('V').text)
            
            hsv_values[song_id].append([h, s, v])
            
            perceived_emotions[song_id] = {}

            for emotion_tag in song_item.find_all('Perceived'):
                for emotion in emotion_tag.find_all(True):  # True: all tags inside 'Perceived'
                    emotion_name = emotion.name
                    v_value = emotion.find('V')
                    a_value = emotion.find('A')

                    # Ensure we only append valid values (not None)
                    if v_value and a_value:
                        v_value = float(v_value.text)
                        a_value = float(a_value.text)

                        # Store the emotion and its V and A values
                        if emotion_name not in perceived_emotions[song_id]:
                            perceived_emotions[song_id][emotion_name] = []

                        perceived_emotions[song_id][emotion_name].append([v_value, a_value])

# calculating averages for HSV and perceived emotions
avg_hsv = {
    song_id: np.mean(values, axis=0) for song_id, values in hsv_values.items()
}
for song_id, emotions in perceived_emotions.items():
    if emotions:
        most_common_emotion = max(emotions, key=lambda x: len(emotions[x]))
        avg_emotion = np.mean(emotions[most_common_emotion], axis=0)
        perceived_emotions[song_id] = (most_common_emotion, avg_emotion)

# printing results of data extraction/processing:
for song_id, hsv in avg_hsv.items():
    print(f"SongID {song_id}: HSV {hsv}, Perceived Emotion {perceived_emotions[song_id]}")
# Out:
# SongID 101: HSV [0.29333333 0.65833333 0.86666667], Perceived Emotion ('Surprise', array([0.8656, 0.5836]))
# SongID 153: HSV [0.38761905 0.67857143 1.        ], Perceived Emotion ('Happiness', array([ 0.6426, -0.2361]))
# SongID 209: HSV [0.47208333 0.6        1.        ], Perceived Emotion ('Gloominess', array([-0.5705, -0.8   ]))
# SongID 242: HSV [0.23995098 0.59558824 0.80882353], Perceived Emotion ('Anger', array([-0.8787,  0.9377]))
# SongID 504: HSV [0.18568376 0.56410256 0.74358974], Perceived Emotion ('Liveliness', array([0.1836, 0.8459]))
# SongID 513: HSV [0.43851351 0.62837838 0.97297297], Perceived Emotion ('Dreamy', array([ 0.2426, -0.2426]))
# SongID 525: HSV [0.28416667 0.75       0.975     ], Perceived Emotion ('Joy', array([0.8066, 0.7016]))
# SongID 551: HSV [0.43062016 0.56976744 0.91860465], Perceived Emotion ('Sadness', array([0.2689, 0.6951]))
# SongID 607: HSV [0.17824074 0.45833333 0.64583333], Perceived Emotion ('Surprise', array([-0.8197,  0.3016]))
# SongID 618: HSV [0.22785714 0.27857143 0.58571429], Perceived Emotion ('Surprise', array([-0.8328, -0.3803]))
# SongID 104: HSV [0.18104167 0.55       0.74375   ], Perceived Emotion ('Fear', array([-0.4656, -0.1824]))
# SongID 172: HSV [0.29282407 0.77083333 0.98611111], Perceived Emotion ('Liveliness', array([0.5246, 0.8197]))
# SongID 204: HSV [0.39134615 0.64423077 0.97596154], Perceived Emotion ('Gloominess', array([-0.8459, -0.5705]))
# SongID 367: HSV [0.17966667 0.46       0.76      ], Perceived Emotion ('Anticipation', array([0.0131, 0.7487]))
# SongID 503: HSV [0.39518519 0.55       0.82222222], Perceived Emotion ('Anger', array([-0.4525,  0.7934]))
# SongID 555: HSV [0.51206897 0.62068966 1.        ], Perceived Emotion ('Longing', array([0.7213, 0.1508]))
# SongID 565: HSV [0.42952381 0.65714286 1.        ], Perceived Emotion ('Sadness', array([0.6492, 0.5115]))
# SongID 109: HSV [0.40762411 0.70212766 0.94680851], Perceived Emotion ('Liveliness', array([ 0.5705, -0.3869]))
# SongID 155: HSV [0.41091954 0.79310345 1.        ], Perceived Emotion ('Surprise', array([0.7672, 0.8525]))
# SongID 156: HSV [0.43214286 0.73571429 1.        ], Perceived Emotion ('Surprise', array([0.    , 0.2164]))
# SongID 181: HSV [0.42660256 0.57692308 0.94230769], Perceived Emotion ('Sadness', array([-0.9902, -0.8328]))
# SongID 190: HSV [0.46119792 0.546875   0.90625   ], Perceived Emotion ('Surprise', array([-0.8197, -0.8328]))
# SongID 196: HSV [0.46081081 0.56081081 0.89189189], Perceived Emotion ('Calmness', array([-0.1836,  0.1705]))
# SongID 404: HSV [0.27172619 0.5625     0.95535714], Perceived Emotion ('Joy', array([0.1377, 0.6361]))
# SongID 539: HSV [0.29444444 0.67424242 0.99242424], Perceived Emotion ('Gloominess', array([-0.2951,  0.1598]))
# SongID 615: HSV [0.10747126 0.18965517 0.43965517], Perceived Emotion ('Fear', array([0.4   , 0.7869]))
# SongID 130: HSV [0.45       0.73484848 1.        ], Perceived Emotion ('Longing', array([0.2885, 0.2492]))
# SongID 161: HSV [0.4245614  0.65131579 0.96710526], Perceived Emotion ('Longing', array([0.3803, 0.3475]))
# SongID 415: HSV [0.27194444 0.56666667 0.95833333], Perceived Emotion ('Relaxed', array([0.0656, 0.5705]))
# SongID 417: HSV [0.26990741 0.61111111 1.        ], Perceived Emotion ('Happiness', array([0.8852, 0.8131]))
# SongID 529: HSV [0.29692029 0.78804348 1.        ], Perceived Emotion ('Liveliness', array([0.118 , 0.2426]))
# SongID 537: HSV [0.36157407 0.64583333 0.98611111], Perceived Emotion ('Longing', array([0.1049, 0.6295]))
# SongID 572: HSV [0.36425439 0.67105263 0.96710526], Perceived Emotion ('Longing', array([ 0.1508, -0.1967]))
# SongID 605: HSV [0.33895349 0.65116279 0.9244186 ], Perceived Emotion ('Fear', array([-0.8656,  0.7213]))
# SongID 616: HSV [0.23074713 0.43965517 0.6637931 ], Perceived Emotion ('Fear', array([-0.9967,  0.3148]))
# SongID 164: HSV [0.39449405 0.46428571 0.89285714], Perceived Emotion ('Anticipation', array([0.177 , 0.3869]))
# SongID 186: HSV [0.28978495 0.47580645 0.85483871], Perceived Emotion ('Joy', array([0.118 , 0.0984]))
# SongID 420: HSV [0.44346847 0.48648649 0.99324324], Perceived Emotion ('Relaxed', array([-0.1639,  0.1639]))
# SongID 515: HSV [0.28617886 0.7804878  1.        ], Perceived Emotion ('Liveliness', array([0.0328, 0.4721]))
# SongID 520: HSV [0.45833333 0.64655172 0.94827586], Perceived Emotion ('Relaxed', array([0.223 , 0.6361]))
# SongID 542: HSV [0.59685185 0.62222222 0.99444444], Perceived Emotion ('Longing', array([ 0.4984, -0.2361]))
# SongID 563: HSV [0.39144144 0.59459459 0.94594595], Perceived Emotion ('Sadness', array([-0.2361,  0.6623]))
# SongID 575: HSV [0.39592199 0.67021277 1.        ], Perceived Emotion ('Dreamy', array([0.4459, 0.1246]))
# SongID 128: HSV [0.39444444 0.65151515 1.        ], Perceived Emotion ('Longing', array([0.4459, 0.577 ]))
# SongID 149: HSV [0.39802632 0.625      1.        ], Perceived Emotion ('Happiness', array([0.9049, 0.7934]))
# SongID 187: HSV [0.42232143 0.55357143 0.99107143], Perceived Emotion ('Dreamy', array([ 0.8787, -0.7082]))
# SongID 197: HSV [0.4125     0.63157895 0.91447368], Perceived Emotion ('Relaxed', array([0.8852, 0.7738]))
# SongID 318: HSV [0.23699187 0.43902439 0.7195122 ], Perceived Emotion ('Inspiring', array([0.0262, 0.459 ]))
# SongID 514: HSV [0.27718254 0.73214286 0.94642857], Perceived Emotion ('Liveliness', array([0.4066, 0.7541]))
# SongID 528: HSV [0.17314815 0.56481481 0.68518519], Perceived Emotion ('Fear', array([-0.4984,  0.6361]))
# SongID 536: HSV [0.41642857 0.71428571 1.        ], Perceived Emotion ('Gloominess', array([0.7475, 0.8787]))
# SongID 562: HSV [0.26990741 0.61805556 0.94444444], Perceived Emotion ('Liveliness', array([0.7738, 0.9705]))
# SongID 136: HSV [0.4012963  0.48333333 0.87222222], Perceived Emotion ('Sadness', array([-0.6426, -0.6361]))
# SongID 184: HSV [0.45546875 0.4375     0.8984375 ], Perceived Emotion ('Dreamy', array([0.1377, 0.2164]))
# SongID 410: HSV [0.22305556 0.83333333 0.975     ], Perceived Emotion ('Happiness', array([0.2033, 0.6164]))
# SongID 502: HSV [0.23047619 0.52857143 0.74285714], Perceived Emotion ('Anticipation', array([-0.0787,  0.3148]))
# SongID 526: HSV [0.38703704 0.73333333 0.97777778], Perceived Emotion ('Inspiring', array([0.8459, 0.9705]))
# SongID 557: HSV [0.378125   0.69791667 0.94791667], Perceived Emotion ('Calmness', array([0.5115, 0.0459]))
# SongID 571: HSV [0.34947917 0.671875   0.9921875 ], Perceived Emotion ('Inspiring', array([0.3607, 0.2885]))
# SongID 129: HSV [0.40691057 0.68292683 1.        ], Perceived Emotion ('Gloominess', array([-0.0262, -0.1443]))
# SongID 195: HSV [0.19811828 0.29032258 0.58870968], Perceived Emotion ('Anticipation', array([0.3803, 0.9377]))
# SongID 414: HSV [0.29944444 0.75833333 0.96666667], Perceived Emotion ('Happiness', array([0.3934, 0.9049]))
# SongID 523: HSV [0.35174419 0.65697674 0.97674419], Perceived Emotion ('Inspiring', array([0.1115, 0.1639]))
# SongID 547: HSV [0.39547619 0.57857143 0.95714286], Perceived Emotion ('Relaxed', array([0.2492, 0.5508]))
# SongID 567: HSV [0.28932292 0.625      0.859375  ], Perceived Emotion ('Relaxed', array([0.0984, 0.5508]))
# SongID 568: HSV [0.23134921 0.74404762 0.94047619], Perceived Emotion ('Liveliness', array([0.1902, 0.2754]))
# SongID 610: HSV [0.43541667 0.54861111 0.89583333], Perceived Emotion ('Surprise', array([0.7934, 0.8197]))
# SongID 126: HSV [0.36666667 0.64473684 0.98026316], Perceived Emotion ('Relaxed', array([0.2426, 0.1377]))
# SongID 406: HSV [0.29692029 0.69021739 0.97282609], Perceived Emotion ('Inspiring', array([0.3475, 0.6295]))
# SongID 409: HSV [0.47028986 0.60869565 0.92391304], Perceived Emotion ('Joy', array([0.7082, 0.4721]))
# SongID 569: HSV [0.48178295 0.69767442 0.95930233], Perceived Emotion ('Liveliness', array([0.5574, 0.4525]))
# SongID 123: HSV [0.24553571 0.84821429 1.        ], Perceived Emotion ('Joy', array([0.4197, 0.3541]))
# SongID 158: HSV [0.47191358 0.49074074 0.94444444], Perceived Emotion ('Gloominess', array([0.118 , 0.1836]))
# SongID 168: HSV [0.27004505 0.29054054 0.64189189], Perceived Emotion ('Anticipation', array([0.4197, 0.3279]))
# SongID 171: HSV [0.30688406 0.89673913 1.        ], Perceived Emotion ('Liveliness', array([0.282 , 0.1443]))
# SongID 180: HSV [0.36666667 0.64655172 0.97413793], Perceived Emotion ('Anticipation', array([0.4393, 0.4996]))
# SongID 267: HSV [0.29926471 0.74264706 0.93382353], Perceived Emotion ('Anticipation', array([0.0984, 0.5836]))
# SongID 505: HSV [0.4045977  0.74137931 0.96551724], Perceived Emotion ('Liveliness', array([0.8197, 0.4066]))
# SongID 561: HSV [0.37641844 0.74468085 1.        ], Perceived Emotion ('Joy', array([-0.0984,  0.177 ]))
# SongID 203: HSV [0.40333333 0.58571429 0.97857143], Perceived Emotion ('Gloominess', array([ 0.0787, -0.0262]))
# SongID 511: HSV [0.24953704 0.54861111 0.83333333], Perceived Emotion ('Gloominess', array([-0.2492, -0.282 ]))
# SongID 564: HSV [0.27786458 0.765625   0.953125  ], Perceived Emotion ('Anticipation', array([0.1836, 0.5836]))
# SongID 578: HSV [0.29444444 0.84090909 1.        ], Perceived Emotion ('Gloominess', array([0.8262, 0.8721]))
# SongID 115: HSV [0.3016129  0.38709677 0.72580645], Perceived Emotion ('Anticipation', array([-0.7869,  0.9639]))
# SongID 127: HSV [0.35471014 0.72826087 1.        ], Perceived Emotion ('Liveliness', array([0.8131, 0.5443]))
# SongID 148: HSV [0.45833333 0.53787879 1.        ], Perceived Emotion ('Joy', array([0.4   , 0.4984]))
# SongID 205: HSV [0.32865854 0.81097561 1.        ], Perceived Emotion ('Happiness', array([0.0852, 0.0984]))
# SongID 574: HSV [0.49958333 0.7        1.        ], Perceived Emotion ('Gloominess', array([ 0.1246, -0.4173]))
# SongID 608: HSV [0.3575 0.575  0.9625], Perceived Emotion ('Longing', array([0.282 , 0.0918]))
# SongID 613: HSV [0.14131944 0.375      0.65625   ], Perceived Emotion ('Anticipation', array([-0.1705,  0.0852]))
# SongID 619: HSV [0.28978495 0.45967742 0.87096774], Perceived Emotion ('Calmness', array([ 0.0984, -0.2492]))
# SongID 534: HSV [0.35833333 0.51515152 0.81818182], Perceived Emotion ('Calmness', array([0.3672, 0.8328]))
# SongID 556: HSV [0.41904762 0.70833333 0.9702381 ], Perceived Emotion ('Happiness', array([0.5508, 0.9705]))
# SongID 573: HSV [0.46504065 0.70731707 1.        ], Perceived Emotion ('Anticipation', array([0.3803, 0.5443]))
# SongID 577: HSV [0.37345679 0.78703704 1.        ], Perceived Emotion ('Gloominess', array([-0.6689, -0.6951]))
# SongID 107: HSV [0.27300725 0.71195652 0.88586957], Perceived Emotion ('Liveliness', array([0.3344, 0.3541]))
# SongID 141: HSV [0.42028302 0.6509434  0.98584906], Perceived Emotion ('Anticipation', array([0.623, 0.577]))
# SongID 177: HSV [0.3295045  0.62837838 0.97972973], Perceived Emotion ('Relaxed', array([0.2885, 0.3672]))
# SongID 544: HSV [0.5775  0.70625 0.9875 ], Perceived Emotion ('Liveliness', array([0.118 , 0.5061]))
# SongID 548: HSV [0.50555556 0.65151515 1.        ], Perceived Emotion ('Relaxed', array([0.3279, 0.8197]))
# SongID 552: HSV [0.275      0.68548387 0.91935484], Perceived Emotion ('Joy', array([0.4721, 0.7016]))
# SongID 553: HSV [0.43421053 0.73684211 1.        ], Perceived Emotion ('Relaxed', array([0.5115, 0.4787]))
# SongID 124: HSV [0.25368217 0.79651163 1.        ], Perceived Emotion ('Liveliness', array([-0.177 , -0.3541]))
# SongID 530: HSV [0.35648148 0.73611111 0.99305556], Perceived Emotion ('Joy', array([0.4393, 0.8459]))
# SongID 535: HSV [0.48259804 0.63235294 1.        ], Perceived Emotion ('Gloominess', array([0.6557, 0.7213]))
# SongID 570: HSV [0.53472222 0.72222222 0.96527778], Perceived Emotion ('Joy', array([0.2754, 0.6164]))
# SongID 147: HSV [0.41468254 0.66666667 1.        ], Perceived Emotion ('Relaxed', array([0.4525, 0.6951]))
# SongID 398: HSV [0.48418803 0.56410256 0.96794872], Perceived Emotion ('Gloominess', array([-0.223 ,  0.2623]))
# SongID 506: HSV [0.29791667 0.57692308 0.87019231], Perceived Emotion ('Gloominess', array([-0.9246, -0.2164]))
# SongID 531: HSV [0.35138889 0.72619048 0.98809524], Perceived Emotion ('Liveliness', array([0.4393, 0.7607]))
# SongID 401: HSV [0.45833333 0.725      1.        ], Perceived Emotion ('Liveliness', array([-0.2885, -0.2426]))
# SongID 519: HSV [0.39195402 0.62931034 0.94827586], Perceived Emotion ('Gloominess', array([-0.1836, -0.1049]))
# SongID 541: HSV [0.40290698 0.70348837 1.        ], Perceived Emotion ('Joy', array([0.6492, 0.3475]))
# SongID 135: HSV [0.4625     0.71022727 0.97727273], Perceived Emotion ('Gloominess', array([-0.4328,  0.6164]))
# SongID 201: HSV [0.41861111 0.64166667 1.        ], Perceived Emotion ('Sadness', array([-0.0656,  0.1049]))
# SongID 133: HSV [0.44554264 0.53488372 0.88953488], Perceived Emotion ('Calmness', array([ 0.1311, -0.8328]))
# SongID 166: HSV [0.29900794 0.47619048 0.76785714], Perceived Emotion ('Surprise', array([0.1836, 0.9508]))
# SongID 501: HSV [0.42465986 0.6122449  0.9744898 ], Perceived Emotion ('Joy', array([0.5967, 0.2754]))
# SongID 165: HSV [0.363 0.54  0.895], Perceived Emotion ('Sadness', array([-0.7148, -0.5115]))
# SongID 559: HSV [0.44568966 0.70689655 1.        ], Perceived Emotion ('Gloominess', array([0.8131, 0.741 ]))
# SongID 604: HSV [0.39467593 0.61111111 0.98611111], Perceived Emotion ('Sadness', array([-0.9377, -0.918 ]))
# SongID 285: HSV [0.34254386 0.69078947 1.        ], Perceived Emotion ('Joy', array([0.518 , 0.4197]))
# SongID 419: HSV [0.29722222 0.82575758 0.99242424], Perceived Emotion ('Joy', array([0.8656, 0.8984]))
# SongID 533: HSV [0.47815315 0.60135135 0.95945946], Perceived Emotion ('Surprise', array([-0.0721,  0.3356]))
# SongID 601: HSV [0.35491453 0.69230769 0.96153846], Perceived Emotion ('Relaxed', array([0.4262, 0.6623]))
# SongID 198: HSV [0.53567708 0.609375   0.984375  ], Perceived Emotion ('Sadness', array([-0.6361, -0.0066]))
# SongID 609: HSV [0.22094017 0.3525641  0.71153846], Perceived Emotion ('Surprise', array([-0.7213,  0.5377]))
# SongID 617: HSV [0.30300926 0.59722222 0.88194444], Perceived Emotion ('Anticipation', array([ 0.577 , -0.3607]))
# SongID 408: HSV [0.31510417 0.546875   0.96354167], Perceived Emotion ('Dreamy', array([ 0.1574, -0.1246]))
# SongID 509: HSV [0.43247863 0.66025641 1.        ], Perceived Emotion ('Anticipation', array([0.5311, 0.4525]))
# SongID 532: HSV [0.24527027 0.82432432 1.        ], Perceived Emotion ('Liveliness', array([0.7475, 0.682 ]))
# SongID 170: HSV [0.35095238 0.45714286 0.77857143], Perceived Emotion ('Anticipation', array([-0.8197, -0.7607]))
# SongID 402: HSV [0.26990741 0.77777778 0.97916667], Perceived Emotion ('Joy', array([0.5377, 0.8262]))
# SongID 580: HSV [0.51111111 0.68181818 1.        ], Perceived Emotion ('Anticipation', array([0.1836, 0.3344]))
# SongID 612: HSV [0.32557471 0.50862069 0.88793103], Perceived Emotion ('Gloominess', array([-0.4   , -0.2754]))
# SongID 173: HSV [0.39017094 0.80128205 0.98076923], Perceived Emotion ('Liveliness', array([0.6426, 0.5311]))
# SongID 614: HSV [0.3496124  0.51162791 0.87790698], Perceived Emotion ('Anticipation', array([ 0.1049, -0.8066]))
# SongID 620: HSV [0.4125     0.58823529 0.95588235], Perceived Emotion ('Relaxed', array([0.518 , 0.4918]))
# SongID 103: HSV [0.12387387 0.45945946 0.68243243], Perceived Emotion ('Surprise', array([0.0131, 0.1115]))
# SongID 518: HSV [0.34454023 0.69827586 1.        ], Perceived Emotion ('Joy', array([0.282 , 0.2164]))
# SongID 418: HSV [0.27017544 0.60526316 0.93421053], Perceived Emotion ('Joy', array([0.2426, 0.4852]))
# SongID 516: HSV [0.32642276 0.82317073 1.        ], Perceived Emotion ('Joy', array([0.8787, 0.918 ]))
# SongID 538: HSV [0.42284946 0.61290323 0.99193548], Perceived Emotion ('Liveliness', array([0.2689, 0.8525]))
# SongID 121: HSV [0.27699275 0.73913043 0.99456522], Perceived Emotion ('Happiness', array([0.518 , 0.3344]))
# SongID 162: HSV [0.25612745 0.33088235 0.72794118], Perceived Emotion ('Longing', array([0.8328, 0.7607]))
# SongID 221: HSV [0.11148649 0.4527027  0.62162162], Perceived Emotion ('Surprise', array([0.4787, 0.3803]))
# SongID 347: HSV [0.36361111 0.8        1.        ], Perceived Emotion ('Joy', array([0.4721, 0.8066]))
# SongID 412: HSV [0.31378205 0.45192308 0.83653846], Perceived Emotion ('Sadness', array([-0.6492, -0.6164]))
# SongID 521: HSV [0.39011628 0.62790698 0.98837209], Perceived Emotion ('Liveliness', array([0.341 , 0.3279]))
# SongID 576: HSV [0.40555556 0.73484848 0.98484848], Perceived Emotion ('Relaxed', array([0.2098, 0.7213]))
# SongID 560: HSV [0.33916667 0.725      0.975     ], Perceived Emotion ('Anticipation', array([0.9049, 0.8459]))
# SongID 416: HSV [0.34920635 0.5        0.95833333], Perceived Emotion ('Gloominess', array([0.4262, 0.3869]))
# SongID 508: HSV [0.38429487 0.85576923 0.99038462], Perceived Emotion ('Dreamy', array([0.0197, 0.9443]))
# SongID 294: HSV [0.41577381 0.55357143 0.97321429], Perceived Emotion ('Joy', array([0.7148, 0.8656]))
# SongID 527: HSV [0.40740741 0.66666667 0.97222222], Perceived Emotion ('Calmness', array([0.1377, 0.2426]))
# SongID 113: HSV [0.40285088 0.53947368 0.86842105], Perceived Emotion ('Fear', array([-0.7541, -0.4066]))
# SongID 413: HSV [0.34527778 0.64166667 0.90833333], Perceived Emotion ('Liveliness', array([-0.6098,  0.716 ]))
# SongID 546: HSV [0.33505747 0.59482759 0.90517241], Perceived Emotion ('Happiness', array([-0.4197, -0.7279]))
# SongID 550: HSV [0.49797297 0.58108108 1.        ], Perceived Emotion ('Longing', array([0.3869, 0.3672]))
# SongID 517: HSV [0.37657658 0.68243243 1.        ], Perceived Emotion ('Relaxed', array([0.3344, 0.4787]))
# SongID 579: HSV [0.41577381 0.67857143 1.        ], Perceived Emotion ('Joy', array([0.4721, 0.5049]))
# SongID 142: HSV [0.433125 0.55     0.9875  ], Perceived Emotion ('Gloominess', array([0.7738, 0.6426]))
# SongID 145: HSV [0.37614943 0.62068966 0.98275862], Perceived Emotion ('Relaxed', array([0.7541, 0.8787]))
# SongID 152: HSV [0.49123932 0.6474359  0.98717949], Perceived Emotion ('Calmness', array([-0.282 , -0.0918]))
# SongID 140: HSV [0.46706349 0.60119048 0.97619048], Perceived Emotion ('Dreamy', array([0.8131, 0.6689]))
# SongID 540: HSV [0.13888889 0.53787879 0.76515152], Perceived Emotion ('Liveliness', array([0.4852, 0.4393]))
# SongID 602: HSV [0.35416667 0.53977273 0.85795455], Perceived Emotion ('Dreamy', array([ 0.8262, -0.1311]))
# SongID 169: HSV [0.19004065 0.43292683 0.63414634], Perceived Emotion ('Surprise', array([0.7738, 0.682 ]))
# SongID 208: HSV [0.42472222 0.51666667 0.98333333], Perceived Emotion ('Dreamy', array([-0.4787,  0.2951]))
# SongID 507: HSV [0.40503876 0.58139535 0.94186047], Perceived Emotion ('Gloominess', array([-0.9311,  0.5115]))
# SongID 202: HSV [0.40652174 0.52173913 0.97826087], Perceived Emotion ('Relaxed', array([0.518 , 0.4197]))
# SongID 207: HSV [0.42777778 0.63541667 0.97916667], Perceived Emotion ('Joy', array([0.7672, 0.7082]))
# SongID 554: HSV [0.55247748 0.66216216 0.99324324], Perceived Emotion ('Gloominess', array([0.7607, 0.9115]))
# SongID 606: HSV [0.2120915  0.43627451 0.76470588], Perceived Emotion ('Fear', array([-0.5115, -0.3344]))
# SongID 188: HSV [0.48063063 0.54054054 0.93243243], Perceived Emotion ('Sadness', array([-0.8262,  0.9443]))
# SongID 139: HSV [0.51333333 0.58571429 1.        ], Perceived Emotion ('Longing', array([0.0852, 0.5508]))
# SongID 143: HSV [0.36666667 0.54069767 1.        ], Perceived Emotion ('Relaxed', array([0.4262, 0.4197]))
# SongID 157: HSV [0.31711712 0.75675676 1.        ], Perceived Emotion ('Calmness', array([0.3738, 0.3344]))
# SongID 566: HSV [0.40215054 0.76612903 1.        ], Perceived Emotion ('Longing', array([0.2557, 0.4787]))
# SongID 110: HSV [0.24209402 0.28205128 0.58974359], Perceived Emotion ('Gloominess', array([-0.2885, -0.0131]))
# SongID 210: HSV [0.44114583 0.6015625  1.        ], Perceived Emotion ('Calmness', array([-0.0066, -0.0459]))
# SongID 510: HSV [0.36034483 0.74137931 0.99137931], Perceived Emotion ('Joy', array([0.7607, 0.7803]))
# SongID 522: HSV [0.47713675 0.68589744 0.95512821], Perceived Emotion ('Relaxed', array([0.3607, 0.8   ]))
# SongID 524: HSV [0.45609756 0.6402439  1.        ], Perceived Emotion ('Joy', array([0.459 , 0.2492]))
# SongID 407: HSV [0.37390351 0.58552632 0.96052632], Perceived Emotion ('Gloominess', array([-0.5705,  0.5729]))
# SongID 603: HSV [0.46074561 0.64473684 0.96052632], Perceived Emotion ('Surprise', array([0.6951, 0.0984]))
# SongID 132: HSV [0.43255208 0.578125   0.8828125 ], Perceived Emotion ('Gloominess', array([-0.1246,  0.    ]))
# SongID 154: HSV [0.49270833 0.55208333 0.98958333], Perceived Emotion ('Relaxed', array([0.4459, 0.3148]))
# SongID 194: HSV [0.23309524 0.32857143 0.64285714], Perceived Emotion ('Fear', array([0.5967, 0.9902]))
# SongID 549: HSV [0.39320175 0.64473684 1.        ], Perceived Emotion ('Sadness', array([-0.5508, -0.0066]))
# SongID 512: HSV [0.34770115 0.70689655 0.9137931 ], Perceived Emotion ('Liveliness', array([0.8459, 0.9311]))
# SongID 411: HSV [0.32435897 0.50641026 0.91666667], Perceived Emotion ('Liveliness', array([ 0.5311, -0.0984]))
# SongID 543: HSV [0.31755952 0.69642857 1.        ], Perceived Emotion ('Liveliness', array([0.0393, 0.4918]))
# SongID 403: HSV [0.38703704 0.53333333 0.94444444], Perceived Emotion ('Joy', array([0.3213, 0.3344]))
# SongID 199: HSV [0.32083333 0.55       0.88333333], Perceived Emotion ('Calmness', array([0.3213, 0.3803]))
# SongID 611: HSV [0.30216049 0.58333333 0.87037037], Perceived Emotion ('Surprise', array([0.223 , 0.4721]))
# SongID 256: HSV [0.45241935 0.61290323 0.96774194], Perceived Emotion ('Liveliness', array([0.859 , 0.1705]))
# SongID 558: HSV [0.3906746  0.67857143 1.        ], Perceived Emotion ('Anticipation', array([0.1508, 0.223 ]))
# SongID 405: HSV [0.31344086 0.63709677 0.95967742], Perceived Emotion ('Anticipation', array([0.3934, 0.1902]))
# SongID 545: HSV [0.46160714 0.66071429 0.91071429], Perceived Emotion ('Calmness', array([0.2361, 0.459 ]))

# %%
# Sort dictionaries by song_id numerically
sorted_avg_hsv = dict(sorted(avg_hsv.items(), key=lambda x: int(x[0])))
sorted_perceived_emotions = dict(sorted(perceived_emotions.items(), key=lambda x: int(x[0])))

# merge dictionaries to create final dataset array, each column would be h, s, v, emotion, v, a
dataset = []
for song_id in sorted_avg_hsv:
    h, s, v = sorted_avg_hsv[song_id]
    emotion, va_array = sorted_perceived_emotions[song_id]
    val, ar = va_array
    dataset.append([song_id, h, s, v, emotion, val, ar])


with open('../../../moodo/dataset.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['SongID', 'H', 'S', 'V', 'Emotion', 'Valence', 'Arousal'])
    writer.writerows(dataset)
